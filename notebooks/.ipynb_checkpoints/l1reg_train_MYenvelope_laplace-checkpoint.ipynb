# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torch.utils.data import Dataset
from IPython.display import Image
import numpy as np
import os
import glob
import random
from PIL import Image
from torch.utils.tensorboard import SummaryWriter
import torchvision.utils as vutils
from skimage.measure import compare_ssim, compare_psnr


#writer = SummaryWriter()
import warnings
warnings.filterwarnings(action='once')


device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device = %s'%device)
print('torch version = %s'%(torch.__version__))
print('no. of GPUs = %d'%(torch.cuda.device_count()))

batch_size, n_in_channels, img_size = 1, 1, 10 #for toy problem
val_batch_size = 1
#dataloader
from torch.utils.data import DataLoader

#custom dataset class 
class ImageDataset(Dataset):
    def __init__(self, root, transforms_= None, unaligned = True, mode = 'train'):
        self.transform = transforms.Compose(transforms_)
        self.unaligned = unaligned

        self.files = sorted(glob.glob(os.path.join(root, '%s/groundtruth'% mode) + '/*.*'))


    def __getitem__(self, index):
        if self.unaligned:
            ground_truth = self.transform(Image.fromarray(np.load(self.files[random.randint(0, len(self.files) - 1)])))
        else:
            ground_truth = self.transform(Image.fromarray(np.load(self.files[index % len(self.files_B)])))
        
        

        return {'ground_truth': ground_truth}

    def __len__(self):
        return len(self.files)
    
transform_train_and_test = [transforms.ToTensor()]
datapath = '../data/l1_toy_data'

#training dataloader: test the performance for unaligned=False, i.e. for aligned/paired data
train_dataloader = DataLoader(ImageDataset(datapath, transforms_=transform_train_and_test, unaligned=False, mode = 'train'),\
                              batch_size = batch_size, shuffle = True) #the samples must be unaligned and shuffled
print('number of minibatches during training = %d'%len(train_dataloader))

#modified sigmoid 
def modified_sigmoid(x, alpha):
    x = 1 + torch.exp(-alpha*x)
    x = torch.div(torch.ones(x.size()).to(device), x)
    return x
# Out:
# device = cpu
# torch version = 1.8.0
# no. of GPUs = 0
# number of minibatches during training = 500

# %%
# Out:
# /opt/tljh/user/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# num_of_angles=200
# num_of_detector_pixels=400
# op_norm = 128.5395
# ODL version = 0.7.0
# astra version = 1.8.3

# %%
#build a convex discriminator (for 10 x 10 inputs)
n_filters = 5 #was 48 previously
filt_dim = 5
n_layers = 10

class icnn_new_model(nn.Module):
    def __init__(self, n_in_channels=1, n_filters=n_filters, filt_dim=filt_dim, n_layers=n_layers):
        super(icnn_new_model, self).__init__()
        
        self.n_layers = n_layers
        #these layers should have non-negative weights
        self.wz = nn.ModuleList([nn.Conv2d(n_filters, n_filters, kernel_size=filt_dim, stride=1, padding=2, bias=False) for i in range(self.n_layers)])
        
        #these layers can have arbitrary weights
        self.wx = nn.ModuleList([nn.Conv2d(n_in_channels, n_filters, kernel_size=filt_dim, stride=1, padding=2, bias=True) for i in range(self.n_layers+1)])
        
        #one final conv layer with nonnegative weights
        self.final_conv2d = nn.Conv2d(n_filters, 1, kernel_size=filt_dim, stride=1, padding=2, bias=False)
        
        #slope of leaky-relu
        self.negative_slope = 0.2 
        
    def forward(self, x):
        z = F.leaky_relu(self.wx[0](x), negative_slope=self.negative_slope)
        for layer in range(self.n_layers):
            z = F.leaky_relu(self.wz[layer](z) + self.wx[layer+1](x), negative_slope=self.negative_slope)
        z = self.final_conv2d(z)
        z_avg = F.avg_pool2d(z, z.size()[2:]).view(z.size()[0], -1)
        
        return z_avg
    

#realize the model: just one net which outputs a small number for true and large for something noisy 
mye = icnn_new_model().to(device) 


#manually initialize weights
#the following are initialized with non-negative weights
def initialize_weights(net, n_layers = n_layers, min_val = 0.0, max_val = 0.001):
    for layer in range(n_layers):
        net.wz[layer].weight.data = min_val + (max_val - min_val) * torch.rand(n_filters,n_filters,filt_dim,filt_dim).to(device)
    
    net.final_conv2d.weight.data = min_val + (max_val - min_val) * torch.rand(1,n_filters,filt_dim,filt_dim).to(device)
    return net

mye = initialize_weights(mye)

#for debugging
dummy_input = torch.rand(batch_size, n_in_channels, img_size, img_size).to(device)
mye_output = mye(dummy_input)
print(mye_output.size())

total_params = sum(p.numel() for p in mye.parameters())
print('total number of parameters in MYE = %d'%total_params)
# Out:
# torch.Size([1, 1])
# total number of parameters in MYE = 7805
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###### FOR DEBUGGING ###### 

#check the contributions of each term in the ACR
noise_sd_for_training_stability = 0.0
for idx, batch in enumerate(train_dataloader):
    ############################################
    images = batch["ground_truth"].to(device) #true images
    fbp = batch["fbp"].to(device) #FBP
    batch_size = images.size()[0]

    #true images + slight noise for stability
    real_x = images + noise_sd_for_training_stability*torch.randn(batch_size,n_in_channels,img_size,img_size).to(device) 
    fake_x = fbp
    
    #for true image
    acr_output = acr(real_x)
    foe_output = foe(real_x)
    l2_net_output = l2_net(real_x)
    print('--- response to true image ---')
    print('contribution of the leaky-relu network = %.6f'%torch.sum(acr_output))
    print('contribution of the FoE network = %.6f'%torch.sum(foe_output))
    print('contribution of the l2-term = %.6f'%torch.sum(l2_net_output))
    
    #for FBP
    acr_output = acr(fake_x)
    foe_output = foe(fake_x)
    l2_net_output = l2_net(fake_x)
    print('--- response to FBP ---')
    print('contribution of the leaky-relu network = %.6f'%torch.sum(acr_output))
    print('contribution of the FoE network = %.6f'%torch.sum(foe_output))
    print('contribution of the l2-term = %.6f'%torch.sum(l2_net_output))
    
    break
# Out:
# --- response to true image ---
# contribution of the leaky-relu network = 0.070020
# contribution of the FoE network = 72.756683
# contribution of the l2-term = 4.494318
# --- response to FBP ---
# contribution of the leaky-relu network = 0.072751
# contribution of the FoE network = 80.585068
# contribution of the l2-term = 4.947651

# %%
#non-negativity penalty
def clamp_weights(net, n_layers = n_layers): #set negative weights to 0
    for layer in range(n_layers):
        net.wz[layer].weight.data.clamp_(0)
    
    net.final_conv2d.weight.data.clamp_(0)
    return net

####### gradient penalty (if needed) #######
import torch.autograd as autograd
def compute_gradient_penalty(net, real_samples, fake_samples):
    """Calculates the gradient penalty loss for WGAN"""
    # Random weight term for interpolation between real and fake samples
    alpha = torch.cuda.FloatTensor(np.random.random((real_samples.size(0), 1, 1, 1)))
    # Get random interpolation between real and fake samples
    interpolates = (alpha * real_samples + ((1 - alpha) * fake_samples)).requires_grad_(True)
    #validity = net(interpolates)
    validity = net(interpolates)
    fake = Variable(torch.cuda.FloatTensor(np.ones(validity.shape)), requires_grad=False)
    # Get gradient w.r.t. interpolates
    gradients = autograd.grad(outputs=validity, inputs=interpolates,
                              grad_outputs=fake, create_graph=True, retain_graph=True,
                              only_inputs=True)[0]
    gradients = gradients.view(gradients.size(0), -1)
    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
    return gradient_penalty
#################################################

# %%
###########
import itertools
betas = (0.5, 0.99) 

#trained without FoE
#optimizer_acr = torch.optim.Adam(itertools.chain(acr.parameters(),l2_net.parameters()), lr=2*1e-5, betas=betas, weight_decay=0.0)

# #when trained with FoE included
optimizer_acr = torch.optim.Adam(acr.parameters(), lr=2*1e-5, betas=betas, weight_decay=0.0)
optimizer_foe = torch.optim.Adam(itertools.chain(foe.parameters(),l2_net.parameters()), lr=2*1e-5, betas=betas, weight_decay=1.0)

lambda_gp = 5.0 #previously 5.0
noise_sd_for_training_stability = 0.0
n_epochs = 10
num_minibatches = 20 #for display

avg_loss_acr_paired = []

for epoch in np.arange(n_epochs):
    
    #restart scheduler and reset losses
    #scheduler_acr = torch.optim.lr_scheduler.StepLR(optimizer_acr, step_size=200, gamma=0.9)
    total_loss = 0.0
    total_gp_loss = 0.0
    total_diff = 0.0
    
    for idx, batch in enumerate(train_dataloader):
        
        ############################################
        images = batch["ground_truth"].to(device) #true images
        fbp = batch["fbp"].to(device) #FBP
        batch_size = images.size()[0]
        
        #true images + slight noise for stability
        real_x = images + noise_sd_for_training_stability*torch.randn(batch_size,n_in_channels,img_size,img_size).to(device) 
        fake_x = fbp
#         alpha_mixing = torch.rand(1).to(device)
#         fake_x = alpha_mixing * real_x + (1-alpha_mixing) * fbp
        
        ############################### optimize net1 to output small value for true and large value for FBP ###############
        #impose 1-Lipschitz condition
        l2_term_true = l2_net(real_x)
        l2_term_fbp = l2_net(fake_x)
        
        
        #use the FoE term
        diff_loss = (acr(real_x).mean() + foe(real_x).mean() + l2_net(real_x).mean())\
        - (acr(fake_x).mean() + foe(fake_x).mean() + l2_net(fake_x).mean())
        
        
#         #Don't use the FoE term
#         diff_loss = (acr(real_x).mean() + l2_net(real_x).mean())\
#         - (acr(fake_x).mean() + l2_net(fake_x).mean())
        
        gp_loss = compute_gradient_penalty(acr, real_x.data, fake_x.data)
        loss = diff_loss + lambda_gp * gp_loss 
        
        #parameter update
        optimizer_acr.zero_grad()
        optimizer_foe.zero_grad()
        loss.backward()
        optimizer_acr.step()
        optimizer_foe.step()
        
        total_loss += loss.item()
        total_gp_loss += gp_loss.item()
        total_diff += diff_loss.item()
        
        #clamp negative weights to 0
        acr = clamp_weights(acr) 
        #take scheduler steps
        #scheduler_acr.step()
        
        if(idx % num_minibatches == num_minibatches-1):
            ####### compute avg. loss over minibatches #######
            avg_loss = total_loss/num_minibatches
            avg_gp_loss = total_gp_loss/num_minibatches
            avg_diff = total_diff/num_minibatches
            
            avg_loss_acr_paired.append(avg_loss)
            
            #reset the losses
            total_loss = 0.0
            total_gp_loss = 0.0
            total_diff = 0.0
            
            print('==================')
            print('----single convex AR----')
            print("epoch: [{}/{}], mini-batch: [{}/{}], avg_loss: {:.8f}, avg_gp_loss: {:.8f}, avg_diff: {:.8f}".\
                  format(epoch+1, n_epochs, idx+1, len(train_dataloader), avg_loss, avg_gp_loss, avg_diff))
            print('l2_factor = %.4e'%((F.softplus(l2_net.l2_penalty))).item()) 
            #print('foe_factor = %.4e'%((F.softplus(acr.penalty))).item()) 
            #print('icnn_factor = %.4e'%((F.softplus(acr.icnn_penalty))).item()) 
            
            print('--- response to true image ---')
            l2_term_true = l2_net(real_x)
            foe_output_true = foe(real_x)
            acr_output_true = acr(real_x)
            print('contribution of the leaky-relu network = %.6f'%torch.sum(acr_output_true))
            print('contribution of the FoE network = %.6f'%torch.sum(foe_output_true))
            print('contribution of the l2-term = %.6f'%torch.sum(l2_term_true))

            l2_term_fbp = l2_net(fake_x)
            foe_output_fbp = foe(fake_x)
            acr_output_fbp = acr(fake_x)
            print('--- response to FBP ---')
            print('contribution of the leaky-relu network = %.6f'%torch.sum(acr_output_fbp))
            print('contribution of the FoE network = %.6f'%torch.sum(foe_output_fbp))
            print('contribution of the l2-term = %.6f'%torch.sum(l2_term_fbp))
    
            #save the models 
            pretrained_network_path = './ver2_pretrained_nets/'
            os.makedirs(pretrained_network_path, exist_ok=True)
#             torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
#             torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
#             torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_" + 'epoch_%02d'%epoch + ".pt") 

            torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_paired.pt") 
            torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_paired.pt") 
            torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_paired.pt")
# Out:
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [20/2250], avg_loss: -4.21911299, avg_gp_loss: 0.99793785, avg_diff: -9.20880222
# l2_factor = 1.2345e-04
# --- response to true image ---
# contribution of the leaky-relu network = 1.062124
# contribution of the FoE network = 69.321632
# contribution of the l2-term = 4.242227
# --- response to FBP ---
# contribution of the leaky-relu network = 1.131312
# contribution of the FoE network = 77.587601
# contribution of the l2-term = 4.683454
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [40/2250], avg_loss: -12.73315187, avg_gp_loss: 0.81893484, avg_diff: -16.82782593
# l2_factor = 1.2350e-04
# --- response to true image ---
# contribution of the leaky-relu network = 453.994568
# contribution of the FoE network = 68.555473
# contribution of the l2-term = 4.313705
# --- response to FBP ---
# contribution of the leaky-relu network = 487.490601
# contribution of the FoE network = 76.834900
# contribution of the l2-term = 4.738015
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [60/2250], avg_loss: -42.61648750, avg_gp_loss: 2.66323234, avg_diff: -55.93264923
# l2_factor = 1.2355e-04
# --- response to true image ---
# contribution of the leaky-relu network = 459.322571
# contribution of the FoE network = 44.921154
# contribution of the l2-term = 2.297378
# --- response to FBP ---
# contribution of the leaky-relu network = 529.835022
# contribution of the FoE network = 54.516449
# contribution of the l2-term = 2.608569
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [80/2250], avg_loss: -82.43503189, avg_gp_loss: 7.80989957, avg_diff: -121.48453064
# l2_factor = 1.2360e-04
# --- response to true image ---
# contribution of the leaky-relu network = 652.491028
# contribution of the FoE network = 42.502598
# contribution of the l2-term = 2.374699
# --- response to FBP ---
# contribution of the leaky-relu network = 787.642273
# contribution of the FoE network = 52.499508
# contribution of the l2-term = 2.666361
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [100/2250], avg_loss: -90.77824478, avg_gp_loss: 10.87277744, avg_diff: -145.14213257
# l2_factor = 1.2365e-04
# --- response to true image ---
# contribution of the leaky-relu network = 425.687408
# contribution of the FoE network = 36.857540
# contribution of the l2-term = 1.195333
# --- response to FBP ---
# contribution of the leaky-relu network = 553.113708
# contribution of the FoE network = 45.743225
# contribution of the l2-term = 1.510363
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [120/2250], avg_loss: -95.74017792, avg_gp_loss: 10.71493386, avg_diff: -149.31484833
# l2_factor = 1.2370e-04
# --- response to true image ---
# contribution of the leaky-relu network = 503.551788
# contribution of the FoE network = 61.436470
# contribution of the l2-term = 3.850657
# --- response to FBP ---
# contribution of the leaky-relu network = 652.720459
# contribution of the FoE network = 70.709236
# contribution of the l2-term = 4.254768
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [140/2250], avg_loss: -104.01489449, avg_gp_loss: 11.81717571, avg_diff: -163.10077209
# l2_factor = 1.2375e-04
# --- response to true image ---
# contribution of the leaky-relu network = 562.134033
# contribution of the FoE network = 71.393776
# contribution of the l2-term = 4.821598
# --- response to FBP ---
# contribution of the leaky-relu network = 719.252197
# contribution of the FoE network = 80.187134
# contribution of the l2-term = 5.278671
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [160/2250], avg_loss: -102.37297287, avg_gp_loss: 12.03429856, avg_diff: -162.54446564
# l2_factor = 1.2380e-04
# --- response to true image ---
# contribution of the leaky-relu network = 370.675323
# contribution of the FoE network = 24.364550
# contribution of the l2-term = 0.820356
# --- response to FBP ---
# contribution of the leaky-relu network = 491.780518
# contribution of the FoE network = 35.230526
# contribution of the l2-term = 1.067858
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [180/2250], avg_loss: -106.19098511, avg_gp_loss: 12.28631444, avg_diff: -167.62255707
# l2_factor = 1.2385e-04
# --- response to true image ---
# contribution of the leaky-relu network = 477.149078
# contribution of the FoE network = 64.639061
# contribution of the l2-term = 3.918042
# --- response to FBP ---
# contribution of the leaky-relu network = 646.946289
# contribution of the FoE network = 73.625542
# contribution of the l2-term = 4.353940
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [200/2250], avg_loss: -98.20693169, avg_gp_loss: 11.45485538, avg_diff: -155.48120880
# l2_factor = 1.2390e-04
# --- response to true image ---
# contribution of the leaky-relu network = 408.195435
# contribution of the FoE network = 49.790581
# contribution of the l2-term = 3.059821
# --- response to FBP ---
# contribution of the leaky-relu network = 542.699768
# contribution of the FoE network = 59.900543
# contribution of the l2-term = 3.398020
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [220/2250], avg_loss: -100.59698181, avg_gp_loss: 11.36185474, avg_diff: -157.40625610
# l2_factor = 1.2395e-04
# --- response to true image ---
# contribution of the leaky-relu network = 408.074188
# contribution of the FoE network = 43.284458
# contribution of the l2-term = 2.416363
# --- response to FBP ---
# contribution of the leaky-relu network = 546.645264
# contribution of the FoE network = 53.598061
# contribution of the l2-term = 2.727030
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [240/2250], avg_loss: -106.80969925, avg_gp_loss: 11.78178765, avg_diff: -165.71863708
# l2_factor = 1.2400e-04
# --- response to true image ---
# contribution of the leaky-relu network = 406.328217
# contribution of the FoE network = 35.210701
# contribution of the l2-term = 1.809529
# --- response to FBP ---
# contribution of the leaky-relu network = 554.992737
# contribution of the FoE network = 45.814137
# contribution of the l2-term = 2.082435
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [260/2250], avg_loss: -105.72487755, avg_gp_loss: 12.66771622, avg_diff: -169.06345978
# l2_factor = 1.2405e-04
# --- response to true image ---
# contribution of the leaky-relu network = 451.082581
# contribution of the FoE network = 68.319740
# contribution of the l2-term = 4.440854
# --- response to FBP ---
# contribution of the leaky-relu network = 615.821777
# contribution of the FoE network = 77.577751
# contribution of the l2-term = 4.898716
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [280/2250], avg_loss: -104.02073212, avg_gp_loss: 11.99471204, avg_diff: -163.99429169
# l2_factor = 1.2410e-04
# --- response to true image ---
# contribution of the leaky-relu network = 388.848969
# contribution of the FoE network = 49.828217
# contribution of the l2-term = 3.069283
# --- response to FBP ---
# contribution of the leaky-relu network = 537.087219
# contribution of the FoE network = 59.982121
# contribution of the l2-term = 3.419252
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [300/2250], avg_loss: -107.48108559, avg_gp_loss: 12.24325569, avg_diff: -168.69736481
# l2_factor = 1.2415e-04
# --- response to true image ---
# contribution of the leaky-relu network = 365.600433
# contribution of the FoE network = 36.985481
# contribution of the l2-term = 1.308375
# --- response to FBP ---
# contribution of the leaky-relu network = 527.018616
# contribution of the FoE network = 46.392483
# contribution of the l2-term = 1.630303
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [320/2250], avg_loss: -110.07109833, avg_gp_loss: 12.29924164, avg_diff: -171.56730652
# l2_factor = 1.2420e-04
# --- response to true image ---
# contribution of the leaky-relu network = 419.281433
# contribution of the FoE network = 41.322426
# contribution of the l2-term = 2.459056
# --- response to FBP ---
# contribution of the leaky-relu network = 572.284363
# contribution of the FoE network = 51.825005
# contribution of the l2-term = 2.754461
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [340/2250], avg_loss: -112.99477882, avg_gp_loss: 13.60471871, avg_diff: -181.01837311
# l2_factor = 1.2425e-04
# --- response to true image ---
# contribution of the leaky-relu network = 458.284363
# contribution of the FoE network = 67.650894
# contribution of the l2-term = 4.616416
# --- response to FBP ---
# contribution of the leaky-relu network = 638.412170
# contribution of the FoE network = 77.263268
# contribution of the l2-term = 5.073187
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [360/2250], avg_loss: -105.91133347, avg_gp_loss: 12.66730964, avg_diff: -169.24788208
# l2_factor = 1.2430e-04
# --- response to true image ---
# contribution of the leaky-relu network = 411.078125
# contribution of the FoE network = 65.562332
# contribution of the l2-term = 4.277544
# --- response to FBP ---
# contribution of the leaky-relu network = 577.680847
# contribution of the FoE network = 75.160217
# contribution of the l2-term = 4.730417
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [380/2250], avg_loss: -106.96461678, avg_gp_loss: 11.82281363, avg_diff: -166.07868500
# l2_factor = 1.2434e-04
# --- response to true image ---
# contribution of the leaky-relu network = 325.284393
# contribution of the FoE network = 22.168762
# contribution of the l2-term = 0.761173
# --- response to FBP ---
# contribution of the leaky-relu network = 471.303192
# contribution of the FoE network = 33.342056
# contribution of the l2-term = 1.005597
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [400/2250], avg_loss: -105.21127396, avg_gp_loss: 12.72364736, avg_diff: -168.82951050
# l2_factor = 1.2439e-04
# --- response to true image ---
# contribution of the leaky-relu network = 404.143158
# contribution of the FoE network = 65.878273
# contribution of the l2-term = 4.449902
# --- response to FBP ---
# contribution of the leaky-relu network = 555.067627
# contribution of the FoE network = 75.360840
# contribution of the l2-term = 4.894964
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [420/2250], avg_loss: -110.47871628, avg_gp_loss: 12.30282662, avg_diff: -171.99284973
# l2_factor = 1.2444e-04
# --- response to true image ---
# contribution of the leaky-relu network = 411.978668
# contribution of the FoE network = 54.024437
# contribution of the l2-term = 3.406088
# --- response to FBP ---
# contribution of the leaky-relu network = 587.048828
# contribution of the FoE network = 64.093002
# contribution of the l2-term = 3.787637
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [440/2250], avg_loss: -111.01454239, avg_gp_loss: 13.02572222, avg_diff: -176.14315338
# l2_factor = 1.2449e-04
# --- response to true image ---
# contribution of the leaky-relu network = 393.811890
# contribution of the FoE network = 41.697552
# contribution of the l2-term = 2.336154
# --- response to FBP ---
# contribution of the leaky-relu network = 542.392944
# contribution of the FoE network = 51.452118
# contribution of the l2-term = 2.638152
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [460/2250], avg_loss: -115.25478477, avg_gp_loss: 13.49284565, avg_diff: -182.71901245
# l2_factor = 1.2454e-04
# --- response to true image ---
# contribution of the leaky-relu network = 417.862915
# contribution of the FoE network = 51.231102
# contribution of the l2-term = 3.127088
# --- response to FBP ---
# contribution of the leaky-relu network = 597.193054
# contribution of the FoE network = 61.255543
# contribution of the l2-term = 3.486523
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [480/2250], avg_loss: -109.62183838, avg_gp_loss: 13.69010949, avg_diff: -178.07238617
# l2_factor = 1.2459e-04
# --- response to true image ---
# contribution of the leaky-relu network = 397.333496
# contribution of the FoE network = 61.718529
# contribution of the l2-term = 4.300086
# --- response to FBP ---
# contribution of the leaky-relu network = 555.555664
# contribution of the FoE network = 71.610413
# contribution of the l2-term = 4.712713
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [500/2250], avg_loss: -107.15014114, avg_gp_loss: 12.17640343, avg_diff: -168.03215790
# l2_factor = 1.2464e-04
# --- response to true image ---
# contribution of the leaky-relu network = 362.776398
# contribution of the FoE network = 40.090210
# contribution of the l2-term = 1.921669
# --- response to FBP ---
# contribution of the leaky-relu network = 519.675110
# contribution of the FoE network = 49.853798
# contribution of the l2-term = 2.235663
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [520/2250], avg_loss: -108.64109688, avg_gp_loss: 12.88924763, avg_diff: -173.08733673
# l2_factor = 1.2469e-04
# --- response to true image ---
# contribution of the leaky-relu network = 344.809357
# contribution of the FoE network = 36.091694
# contribution of the l2-term = 1.700235
# --- response to FBP ---
# contribution of the leaky-relu network = 495.050598
# contribution of the FoE network = 46.242794
# contribution of the l2-term = 1.997887
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [540/2250], avg_loss: -106.40442963, avg_gp_loss: 12.30377977, avg_diff: -167.92332916
# l2_factor = 1.2474e-04
# --- response to true image ---
# contribution of the leaky-relu network = 350.180328
# contribution of the FoE network = 48.545296
# contribution of the l2-term = 2.900681
# --- response to FBP ---
# contribution of the leaky-relu network = 502.268585
# contribution of the FoE network = 58.611485
# contribution of the l2-term = 3.249616
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [560/2250], avg_loss: -106.57478333, avg_gp_loss: 11.11577301, avg_diff: -162.15364838
# l2_factor = 1.2479e-04
# --- response to true image ---
# contribution of the leaky-relu network = 478.279968
# contribution of the FoE network = 63.237038
# contribution of the l2-term = 4.189000
# --- response to FBP ---
# contribution of the leaky-relu network = 679.014587
# contribution of the FoE network = 73.160339
# contribution of the l2-term = 4.638564
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [580/2250], avg_loss: -104.78827477, avg_gp_loss: 12.73536444, avg_diff: -168.46509705
# l2_factor = 1.2484e-04
# --- response to true image ---
# contribution of the leaky-relu network = 418.753296
# contribution of the FoE network = 63.368874
# contribution of the l2-term = 4.189390
# --- response to FBP ---
# contribution of the leaky-relu network = 594.657227
# contribution of the FoE network = 73.293922
# contribution of the l2-term = 4.637937
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [600/2250], avg_loss: -105.10579224, avg_gp_loss: 12.29645786, avg_diff: -166.58808289
# l2_factor = 1.2489e-04
# --- response to true image ---
# contribution of the leaky-relu network = 358.183197
# contribution of the FoE network = 45.404423
# contribution of the l2-term = 2.819750
# --- response to FBP ---
# contribution of the leaky-relu network = 513.476501
# contribution of the FoE network = 55.890034
# contribution of the l2-term = 3.145684
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [620/2250], avg_loss: -104.00422668, avg_gp_loss: 11.68741508, avg_diff: -162.44130249
# l2_factor = 1.2494e-04
# --- response to true image ---
# contribution of the leaky-relu network = 463.706787
# contribution of the FoE network = 64.346046
# contribution of the l2-term = 4.650037
# --- response to FBP ---
# contribution of the leaky-relu network = 632.212891
# contribution of the FoE network = 74.205490
# contribution of the l2-term = 5.089612
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [640/2250], avg_loss: -108.36309395, avg_gp_loss: 12.30167468, avg_diff: -169.87146759
# l2_factor = 1.2499e-04
# --- response to true image ---
# contribution of the leaky-relu network = 325.093048
# contribution of the FoE network = 34.690910
# contribution of the l2-term = 1.211863
# --- response to FBP ---
# contribution of the leaky-relu network = 497.644501
# contribution of the FoE network = 44.562145
# contribution of the l2-term = 1.533170
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [660/2250], avg_loss: -113.86301193, avg_gp_loss: 14.32252402, avg_diff: -185.47563324
# l2_factor = 1.2504e-04
# --- response to true image ---
# contribution of the leaky-relu network = 359.608765
# contribution of the FoE network = 45.965809
# contribution of the l2-term = 2.938954
# --- response to FBP ---
# contribution of the leaky-relu network = 514.695557
# contribution of the FoE network = 56.214241
# contribution of the l2-term = 3.266136
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [680/2250], avg_loss: -116.26502380, avg_gp_loss: 14.09059405, avg_diff: -186.71799469
# l2_factor = 1.2509e-04
# --- response to true image ---
# contribution of the leaky-relu network = 281.227997
# contribution of the FoE network = 31.476538
# contribution of the l2-term = 1.311574
# --- response to FBP ---
# contribution of the leaky-relu network = 425.403931
# contribution of the FoE network = 42.042667
# contribution of the l2-term = 1.595533
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [700/2250], avg_loss: -111.04788818, avg_gp_loss: 13.02930555, avg_diff: -176.19441528
# l2_factor = 1.2514e-04
# --- response to true image ---
# contribution of the leaky-relu network = 352.350555
# contribution of the FoE network = 53.551662
# contribution of the l2-term = 3.566136
# --- response to FBP ---
# contribution of the leaky-relu network = 496.607086
# contribution of the FoE network = 63.501621
# contribution of the l2-term = 3.933948
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [720/2250], avg_loss: -105.44080658, avg_gp_loss: 11.76023178, avg_diff: -164.24196472
# l2_factor = 1.2519e-04
# --- response to true image ---
# contribution of the leaky-relu network = 324.688049
# contribution of the FoE network = 39.157532
# contribution of the l2-term = 1.869476
# --- response to FBP ---
# contribution of the leaky-relu network = 471.574799
# contribution of the FoE network = 48.949913
# contribution of the l2-term = 2.183946
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [740/2250], avg_loss: -110.14957619, avg_gp_loss: 12.96246622, avg_diff: -174.96190796
# l2_factor = 1.2524e-04
# --- response to true image ---
# contribution of the leaky-relu network = 397.262604
# contribution of the FoE network = 49.332951
# contribution of the l2-term = 3.116793
# --- response to FBP ---
# contribution of the leaky-relu network = 555.288086
# contribution of the FoE network = 59.010654
# contribution of the l2-term = 3.463788
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [760/2250], avg_loss: -111.20527077, avg_gp_loss: 12.90097404, avg_diff: -175.71014099
# l2_factor = 1.2529e-04
# --- response to true image ---
# contribution of the leaky-relu network = 371.286224
# contribution of the FoE network = 52.145363
# contribution of the l2-term = 3.049054
# --- response to FBP ---
# contribution of the leaky-relu network = 545.170227
# contribution of the FoE network = 62.073627
# contribution of the l2-term = 3.424060
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [780/2250], avg_loss: -115.39243164, avg_gp_loss: 13.03827219, avg_diff: -180.58379211
# l2_factor = 1.2534e-04
# --- response to true image ---
# contribution of the leaky-relu network = 410.834930
# contribution of the FoE network = 52.919708
# contribution of the l2-term = 3.502417
# --- response to FBP ---
# contribution of the leaky-relu network = 602.163818
# contribution of the FoE network = 63.330898
# contribution of the l2-term = 3.878465
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [800/2250], avg_loss: -105.71502762, avg_gp_loss: 12.83694584, avg_diff: -169.89975739
# l2_factor = 1.2540e-04
# --- response to true image ---
# contribution of the leaky-relu network = 396.804016
# contribution of the FoE network = 63.448013
# contribution of the l2-term = 4.276034
# --- response to FBP ---
# contribution of the leaky-relu network = 575.720032
# contribution of the FoE network = 73.563118
# contribution of the l2-term = 4.724344
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [820/2250], avg_loss: -114.28723793, avg_gp_loss: 13.03889279, avg_diff: -179.48170166
# l2_factor = 1.2545e-04
# --- response to true image ---
# contribution of the leaky-relu network = 411.227875
# contribution of the FoE network = 51.333179
# contribution of the l2-term = 3.123477
# --- response to FBP ---
# contribution of the leaky-relu network = 599.051819
# contribution of the FoE network = 61.269066
# contribution of the l2-term = 3.490566
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [840/2250], avg_loss: -109.35669479, avg_gp_loss: 13.37746854, avg_diff: -176.24403839
# l2_factor = 1.2550e-04
# --- response to true image ---
# contribution of the leaky-relu network = 332.565948
# contribution of the FoE network = 43.102978
# contribution of the l2-term = 2.570639
# --- response to FBP ---
# contribution of the leaky-relu network = 478.122742
# contribution of the FoE network = 53.143600
# contribution of the l2-term = 2.890446
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [860/2250], avg_loss: -109.80340080, avg_gp_loss: 12.87852979, avg_diff: -174.19605103
# l2_factor = 1.2555e-04
# --- response to true image ---
# contribution of the leaky-relu network = 338.480255
# contribution of the FoE network = 47.016270
# contribution of the l2-term = 2.859721
# --- response to FBP ---
# contribution of the leaky-relu network = 487.944336
# contribution of the FoE network = 56.930122
# contribution of the l2-term = 3.200025
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [880/2250], avg_loss: -104.39885330, avg_gp_loss: 11.99328456, avg_diff: -164.36527557
# l2_factor = 1.2560e-04
# --- response to true image ---
# contribution of the leaky-relu network = 378.898926
# contribution of the FoE network = 60.293362
# contribution of the l2-term = 4.073291
# --- response to FBP ---
# contribution of the leaky-relu network = 538.024597
# contribution of the FoE network = 70.317886
# contribution of the l2-term = 4.493837
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [900/2250], avg_loss: -115.53324776, avg_gp_loss: 13.32261012, avg_diff: -182.14629822
# l2_factor = 1.2565e-04
# --- response to true image ---
# contribution of the leaky-relu network = 343.682861
# contribution of the FoE network = 42.322990
# contribution of the l2-term = 2.381719
# --- response to FBP ---
# contribution of the leaky-relu network = 514.522705
# contribution of the FoE network = 52.840919
# contribution of the l2-term = 2.699954
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [920/2250], avg_loss: -113.60200539, avg_gp_loss: 13.89092703, avg_diff: -183.05664062
# l2_factor = 1.2570e-04
# --- response to true image ---
# contribution of the leaky-relu network = 357.952240
# contribution of the FoE network = 68.599503
# contribution of the l2-term = 4.974418
# --- response to FBP ---
# contribution of the leaky-relu network = 520.487793
# contribution of the FoE network = 78.757172
# contribution of the l2-term = 5.458165
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [940/2250], avg_loss: -107.75760117, avg_gp_loss: 11.91196423, avg_diff: -167.31742249
# l2_factor = 1.2575e-04
# --- response to true image ---
# contribution of the leaky-relu network = 320.810089
# contribution of the FoE network = 34.216438
# contribution of the l2-term = 1.220438
# --- response to FBP ---
# contribution of the leaky-relu network = 494.712311
# contribution of the FoE network = 44.195705
# contribution of the l2-term = 1.535089
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [960/2250], avg_loss: -106.88012619, avg_gp_loss: 12.47917449, avg_diff: -169.27599792
# l2_factor = 1.2580e-04
# --- response to true image ---
# contribution of the leaky-relu network = 433.225403
# contribution of the FoE network = 62.450329
# contribution of the l2-term = 4.045064
# --- response to FBP ---
# contribution of the leaky-relu network = 619.557617
# contribution of the FoE network = 72.478424
# contribution of the l2-term = 4.486821
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [980/2250], avg_loss: -110.44868355, avg_gp_loss: 13.02533507, avg_diff: -175.57535858
# l2_factor = 1.2585e-04
# --- response to true image ---
# contribution of the leaky-relu network = 360.562988
# contribution of the FoE network = 50.472404
# contribution of the l2-term = 3.035359
# --- response to FBP ---
# contribution of the leaky-relu network = 521.861816
# contribution of the FoE network = 60.433956
# contribution of the l2-term = 3.394446
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1000/2250], avg_loss: -107.03131027, avg_gp_loss: 12.22531686, avg_diff: -168.15789337
# l2_factor = 1.2590e-04
# --- response to true image ---
# contribution of the leaky-relu network = 394.317444
# contribution of the FoE network = 49.156124
# contribution of the l2-term = 2.944983
# --- response to FBP ---
# contribution of the leaky-relu network = 557.970032
# contribution of the FoE network = 58.725307
# contribution of the l2-term = 3.294198
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1020/2250], avg_loss: -109.14722824, avg_gp_loss: 13.07423322, avg_diff: -174.51839447
# l2_factor = 1.2595e-04
# --- response to true image ---
# contribution of the leaky-relu network = 269.282623
# contribution of the FoE network = 24.992308
# contribution of the l2-term = 0.934071
# --- response to FBP ---
# contribution of the leaky-relu network = 407.115662
# contribution of the FoE network = 35.782780
# contribution of the l2-term = 1.188816
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1040/2250], avg_loss: -110.45330276, avg_gp_loss: 12.64844155, avg_diff: -173.69551086
# l2_factor = 1.2600e-04
# --- response to true image ---
# contribution of the leaky-relu network = 389.436188
# contribution of the FoE network = 54.487431
# contribution of the l2-term = 3.452368
# --- response to FBP ---
# contribution of the leaky-relu network = 559.671204
# contribution of the FoE network = 64.861191
# contribution of the l2-term = 3.837476
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1060/2250], avg_loss: -109.73777580, avg_gp_loss: 12.85287392, avg_diff: -174.00214539
# l2_factor = 1.2605e-04
# --- response to true image ---
# contribution of the leaky-relu network = 319.908752
# contribution of the FoE network = 43.778774
# contribution of the l2-term = 2.544813
# --- response to FBP ---
# contribution of the leaky-relu network = 465.126465
# contribution of the FoE network = 54.156029
# contribution of the l2-term = 2.864148
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1080/2250], avg_loss: -108.59188652, avg_gp_loss: 12.51886454, avg_diff: -171.18620911
# l2_factor = 1.2610e-04
# --- response to true image ---
# contribution of the leaky-relu network = 291.521149
# contribution of the FoE network = 34.964287
# contribution of the l2-term = 1.235298
# --- response to FBP ---
# contribution of the leaky-relu network = 448.356995
# contribution of the FoE network = 44.846149
# contribution of the l2-term = 1.550319
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1100/2250], avg_loss: -111.66719208, avg_gp_loss: 12.73298321, avg_diff: -175.33210754
# l2_factor = 1.2615e-04
# --- response to true image ---
# contribution of the leaky-relu network = 406.338928
# contribution of the FoE network = 52.492401
# contribution of the l2-term = 2.959759
# --- response to FBP ---
# contribution of the leaky-relu network = 590.587402
# contribution of the FoE network = 62.496796
# contribution of the l2-term = 3.337735
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1120/2250], avg_loss: -108.67779655, avg_gp_loss: 13.05359483, avg_diff: -173.94577026
# l2_factor = 1.2620e-04
# --- response to true image ---
# contribution of the leaky-relu network = 351.199799
# contribution of the FoE network = 57.589161
# contribution of the l2-term = 3.670464
# --- response to FBP ---
# contribution of the leaky-relu network = 506.894379
# contribution of the FoE network = 67.721870
# contribution of the l2-term = 4.073117
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1140/2250], avg_loss: -105.68064461, avg_gp_loss: 12.25163651, avg_diff: -166.93882599
# l2_factor = 1.2625e-04
# --- response to true image ---
# contribution of the leaky-relu network = 295.891632
# contribution of the FoE network = 37.781673
# contribution of the l2-term = 2.054085
# --- response to FBP ---
# contribution of the leaky-relu network = 426.226257
# contribution of the FoE network = 47.763409
# contribution of the l2-term = 2.338482
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1160/2250], avg_loss: -111.43235970, avg_gp_loss: 12.51926756, avg_diff: -174.02869720
# l2_factor = 1.2630e-04
# --- response to true image ---
# contribution of the leaky-relu network = 360.130066
# contribution of the FoE network = 43.838787
# contribution of the l2-term = 2.546184
# --- response to FBP ---
# contribution of the leaky-relu network = 522.048889
# contribution of the FoE network = 53.986977
# contribution of the l2-term = 2.866071
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1180/2250], avg_loss: -115.07574501, avg_gp_loss: 14.27259600, avg_diff: -186.43872528
# l2_factor = 1.2635e-04
# --- response to true image ---
# contribution of the leaky-relu network = 378.285034
# contribution of the FoE network = 68.119293
# contribution of the l2-term = 4.654898
# --- response to FBP ---
# contribution of the leaky-relu network = 534.383362
# contribution of the FoE network = 77.977188
# contribution of the l2-term = 5.117202
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1200/2250], avg_loss: -108.30918427, avg_gp_loss: 12.25762944, avg_diff: -169.59733124
# l2_factor = 1.2640e-04
# --- response to true image ---
# contribution of the leaky-relu network = 383.957764
# contribution of the FoE network = 64.160179
# contribution of the l2-term = 4.183519
# --- response to FBP ---
# contribution of the leaky-relu network = 546.299377
# contribution of the FoE network = 74.033363
# contribution of the l2-term = 4.619671
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1220/2250], avg_loss: -110.20931702, avg_gp_loss: 12.86663034, avg_diff: -174.54246826
# l2_factor = 1.2645e-04
# --- response to true image ---
# contribution of the leaky-relu network = 341.984344
# contribution of the FoE network = 45.822269
# contribution of the l2-term = 2.833556
# --- response to FBP ---
# contribution of the leaky-relu network = 491.971008
# contribution of the FoE network = 56.108570
# contribution of the l2-term = 3.150505
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1240/2250], avg_loss: -111.14830513, avg_gp_loss: 12.56781778, avg_diff: -173.98739471
# l2_factor = 1.2650e-04
# --- response to true image ---
# contribution of the leaky-relu network = 312.762970
# contribution of the FoE network = 36.235409
# contribution of the l2-term = 1.265767
# --- response to FBP ---
# contribution of the leaky-relu network = 490.333008
# contribution of the FoE network = 45.961903
# contribution of the l2-term = 1.585038
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1260/2250], avg_loss: -105.40682526, avg_gp_loss: 12.44863515, avg_diff: -167.65000000
# l2_factor = 1.2656e-04
# --- response to true image ---
# contribution of the leaky-relu network = 392.467896
# contribution of the FoE network = 67.018402
# contribution of the l2-term = 4.267467
# --- response to FBP ---
# contribution of the leaky-relu network = 562.302979
# contribution of the FoE network = 76.757370
# contribution of the l2-term = 4.723702
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1280/2250], avg_loss: -112.01007233, avg_gp_loss: 13.33429296, avg_diff: -178.68153687
# l2_factor = 1.2661e-04
# --- response to true image ---
# contribution of the leaky-relu network = 347.851074
# contribution of the FoE network = 47.280495
# contribution of the l2-term = 2.244827
# --- response to FBP ---
# contribution of the leaky-relu network = 522.758667
# contribution of the FoE network = 57.164482
# contribution of the l2-term = 2.604338
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1300/2250], avg_loss: -108.49003448, avg_gp_loss: 12.01379542, avg_diff: -168.55901184
# l2_factor = 1.2666e-04
# --- response to true image ---
# contribution of the leaky-relu network = 359.482544
# contribution of the FoE network = 45.754875
# contribution of the l2-term = 2.314806
# --- response to FBP ---
# contribution of the leaky-relu network = 538.513855
# contribution of the FoE network = 55.801559
# contribution of the l2-term = 2.658333
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1320/2250], avg_loss: -107.91982689, avg_gp_loss: 12.90846643, avg_diff: -172.46215973
# l2_factor = 1.2671e-04
# --- response to true image ---
# contribution of the leaky-relu network = 356.127960
# contribution of the FoE network = 45.162788
# contribution of the l2-term = 2.568693
# --- response to FBP ---
# contribution of the leaky-relu network = 521.650879
# contribution of the FoE network = 55.359840
# contribution of the l2-term = 2.891045
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1340/2250], avg_loss: -109.55361137, avg_gp_loss: 13.17780800, avg_diff: -175.44264984
# l2_factor = 1.2676e-04
# --- response to true image ---
# contribution of the leaky-relu network = 296.700409
# contribution of the FoE network = 37.808537
# contribution of the l2-term = 1.996405
# --- response to FBP ---
# contribution of the leaky-relu network = 434.354340
# contribution of the FoE network = 47.717945
# contribution of the l2-term = 2.279975
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1360/2250], avg_loss: -114.25199356, avg_gp_loss: 13.51720121, avg_diff: -181.83800049
# l2_factor = 1.2681e-04
# --- response to true image ---
# contribution of the leaky-relu network = 270.238678
# contribution of the FoE network = 31.722738
# contribution of the l2-term = 1.333730
# --- response to FBP ---
# contribution of the leaky-relu network = 410.528290
# contribution of the FoE network = 42.003574
# contribution of the l2-term = 1.615993
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1380/2250], avg_loss: -111.34143333, avg_gp_loss: 12.60491984, avg_diff: -174.36603241
# l2_factor = 1.2686e-04
# --- response to true image ---
# contribution of the leaky-relu network = 372.613770
# contribution of the FoE network = 51.283890
# contribution of the l2-term = 3.041646
# --- response to FBP ---
# contribution of the leaky-relu network = 544.596558
# contribution of the FoE network = 61.489407
# contribution of the l2-term = 3.396107
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1400/2250], avg_loss: -111.73850441, avg_gp_loss: 12.90703773, avg_diff: -176.27369232
# l2_factor = 1.2691e-04
# --- response to true image ---
# contribution of the leaky-relu network = 300.696350
# contribution of the FoE network = 23.236692
# contribution of the l2-term = 0.777294
# --- response to FBP ---
# contribution of the leaky-relu network = 470.222534
# contribution of the FoE network = 34.022598
# contribution of the l2-term = 1.026306
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1420/2250], avg_loss: -105.66836243, avg_gp_loss: 12.60382230, avg_diff: -168.68747406
# l2_factor = 1.2696e-04
# --- response to true image ---
# contribution of the leaky-relu network = 311.601807
# contribution of the FoE network = 32.417217
# contribution of the l2-term = 1.525562
# --- response to FBP ---
# contribution of the leaky-relu network = 452.478821
# contribution of the FoE network = 42.331692
# contribution of the l2-term = 1.794125
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1440/2250], avg_loss: -112.37224617, avg_gp_loss: 13.49154055, avg_diff: -179.82994843
# l2_factor = 1.2701e-04
# --- response to true image ---
# contribution of the leaky-relu network = 323.569885
# contribution of the FoE network = 43.069489
# contribution of the l2-term = 2.522135
# --- response to FBP ---
# contribution of the leaky-relu network = 462.873047
# contribution of the FoE network = 52.893364
# contribution of the l2-term = 2.821361
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1460/2250], avg_loss: -106.61339569, avg_gp_loss: 12.44518044, avg_diff: -168.83929749
# l2_factor = 1.2706e-04
# --- response to true image ---
# contribution of the leaky-relu network = 257.059814
# contribution of the FoE network = 24.773611
# contribution of the l2-term = 0.840608
# --- response to FBP ---
# contribution of the leaky-relu network = 392.233551
# contribution of the FoE network = 35.376522
# contribution of the l2-term = 1.094158
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1480/2250], avg_loss: -106.04594917, avg_gp_loss: 11.92173784, avg_diff: -165.65463867
# l2_factor = 1.2711e-04
# --- response to true image ---
# contribution of the leaky-relu network = 363.677917
# contribution of the FoE network = 47.778275
# contribution of the l2-term = 2.618423
# --- response to FBP ---
# contribution of the leaky-relu network = 531.910461
# contribution of the FoE network = 58.088596
# contribution of the l2-term = 2.953425
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1500/2250], avg_loss: -108.22671356, avg_gp_loss: 12.60673156, avg_diff: -171.26037140
# l2_factor = 1.2717e-04
# --- response to true image ---
# contribution of the leaky-relu network = 373.247253
# contribution of the FoE network = 59.930363
# contribution of the l2-term = 3.809552
# --- response to FBP ---
# contribution of the leaky-relu network = 533.407532
# contribution of the FoE network = 69.875023
# contribution of the l2-term = 4.202836
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1520/2250], avg_loss: -109.43350830, avg_gp_loss: 12.43567266, avg_diff: -171.61187134
# l2_factor = 1.2722e-04
# --- response to true image ---
# contribution of the leaky-relu network = 394.762512
# contribution of the FoE network = 63.259792
# contribution of the l2-term = 4.142042
# --- response to FBP ---
# contribution of the leaky-relu network = 562.197449
# contribution of the FoE network = 73.298027
# contribution of the l2-term = 4.557874
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1540/2250], avg_loss: -106.74733658, avg_gp_loss: 12.58310709, avg_diff: -169.66287231
# l2_factor = 1.2727e-04
# --- response to true image ---
# contribution of the leaky-relu network = 373.270721
# contribution of the FoE network = 52.916210
# contribution of the l2-term = 3.308628
# --- response to FBP ---
# contribution of the leaky-relu network = 517.101074
# contribution of the FoE network = 62.251030
# contribution of the l2-term = 3.651625
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1560/2250], avg_loss: -108.89298019, avg_gp_loss: 12.81432204, avg_diff: -172.96459045
# l2_factor = 1.2732e-04
# --- response to true image ---
# contribution of the leaky-relu network = 341.123993
# contribution of the FoE network = 54.142330
# contribution of the l2-term = 3.169732
# --- response to FBP ---
# contribution of the leaky-relu network = 486.513855
# contribution of the FoE network = 63.814022
# contribution of the l2-term = 3.527410
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1580/2250], avg_loss: -110.85062332, avg_gp_loss: 12.72434509, avg_diff: -174.47234955
# l2_factor = 1.2737e-04
# --- response to true image ---
# contribution of the leaky-relu network = 301.311096
# contribution of the FoE network = 31.841667
# contribution of the l2-term = 1.527532
# --- response to FBP ---
# contribution of the leaky-relu network = 452.954926
# contribution of the FoE network = 42.492241
# contribution of the l2-term = 1.784426
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1600/2250], avg_loss: -110.20617256, avg_gp_loss: 12.93220174, avg_diff: -174.86718140
# l2_factor = 1.2742e-04
# --- response to true image ---
# contribution of the leaky-relu network = 338.839539
# contribution of the FoE network = 51.460281
# contribution of the l2-term = 3.008336
# --- response to FBP ---
# contribution of the leaky-relu network = 491.932251
# contribution of the FoE network = 61.642590
# contribution of the l2-term = 3.357697
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1620/2250], avg_loss: -107.38887405, avg_gp_loss: 12.54058979, avg_diff: -170.09182281
# l2_factor = 1.2747e-04
# --- response to true image ---
# contribution of the leaky-relu network = 335.069885
# contribution of the FoE network = 54.604393
# contribution of the l2-term = 3.289410
# --- response to FBP ---
# contribution of the leaky-relu network = 483.871704
# contribution of the FoE network = 64.786263
# contribution of the l2-term = 3.649646
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1640/2250], avg_loss: -107.66794891, avg_gp_loss: 12.34287755, avg_diff: -169.38233643
# l2_factor = 1.2752e-04
# --- response to true image ---
# contribution of the leaky-relu network = 313.740814
# contribution of the FoE network = 36.909729
# contribution of the l2-term = 1.827407
# --- response to FBP ---
# contribution of the leaky-relu network = 469.557526
# contribution of the FoE network = 47.464432
# contribution of the l2-term = 2.107555
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1660/2250], avg_loss: -110.34128609, avg_gp_loss: 12.35818048, avg_diff: -172.13218842
# l2_factor = 1.2757e-04
# --- response to true image ---
# contribution of the leaky-relu network = 367.604370
# contribution of the FoE network = 41.065964
# contribution of the l2-term = 1.361745
# --- response to FBP ---
# contribution of the leaky-relu network = 563.667664
# contribution of the FoE network = 50.456470
# contribution of the l2-term = 1.694566
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1680/2250], avg_loss: -113.75423012, avg_gp_loss: 13.22834787, avg_diff: -179.89596863
# l2_factor = 1.2762e-04
# --- response to true image ---
# contribution of the leaky-relu network = 376.272247
# contribution of the FoE network = 51.071007
# contribution of the l2-term = 2.295659
# --- response to FBP ---
# contribution of the leaky-relu network = 563.895325
# contribution of the FoE network = 60.732948
# contribution of the l2-term = 2.661091
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1700/2250], avg_loss: -109.00243263, avg_gp_loss: 13.17835913, avg_diff: -174.89422913
# l2_factor = 1.2768e-04
# --- response to true image ---
# contribution of the leaky-relu network = 356.731689
# contribution of the FoE network = 51.849701
# contribution of the l2-term = 3.046840
# --- response to FBP ---
# contribution of the leaky-relu network = 515.694275
# contribution of the FoE network = 62.119946
# contribution of the l2-term = 3.380953
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1720/2250], avg_loss: -112.44809761, avg_gp_loss: 13.15041564, avg_diff: -178.20017548
# l2_factor = 1.2773e-04
# --- response to true image ---
# contribution of the leaky-relu network = 342.698853
# contribution of the FoE network = 49.822300
# contribution of the l2-term = 2.156807
# --- response to FBP ---
# contribution of the leaky-relu network = 526.377686
# contribution of the FoE network = 59.681583
# contribution of the l2-term = 2.517129
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1740/2250], avg_loss: -109.00945129, avg_gp_loss: 12.87670283, avg_diff: -173.39296570
# l2_factor = 1.2778e-04
# --- response to true image ---
# contribution of the leaky-relu network = 330.364655
# contribution of the FoE network = 50.240051
# contribution of the l2-term = 2.806724
# --- response to FBP ---
# contribution of the leaky-relu network = 488.866150
# contribution of the FoE network = 60.534313
# contribution of the l2-term = 3.136280
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1760/2250], avg_loss: -112.72635841, avg_gp_loss: 13.45064073, avg_diff: -179.97956238
# l2_factor = 1.2783e-04
# --- response to true image ---
# contribution of the leaky-relu network = 369.220306
# contribution of the FoE network = 69.506104
# contribution of the l2-term = 4.200847
# --- response to FBP ---
# contribution of the leaky-relu network = 526.442627
# contribution of the FoE network = 79.112747
# contribution of the l2-term = 4.632258
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1780/2250], avg_loss: -109.91540909, avg_gp_loss: 13.06020737, avg_diff: -175.21644745
# l2_factor = 1.2788e-04
# --- response to true image ---
# contribution of the leaky-relu network = 290.554871
# contribution of the FoE network = 48.383263
# contribution of the l2-term = 2.237550
# --- response to FBP ---
# contribution of the leaky-relu network = 439.531158
# contribution of the FoE network = 58.290379
# contribution of the l2-term = 2.581075
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1800/2250], avg_loss: -105.72207985, avg_gp_loss: 11.73862259, avg_diff: -164.41519165
# l2_factor = 1.2793e-04
# --- response to true image ---
# contribution of the leaky-relu network = 305.769287
# contribution of the FoE network = 39.600525
# contribution of the l2-term = 1.374931
# --- response to FBP ---
# contribution of the leaky-relu network = 475.624390
# contribution of the FoE network = 49.410500
# contribution of the l2-term = 1.691152
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1820/2250], avg_loss: -108.60163040, avg_gp_loss: 12.88448811, avg_diff: -173.02407074
# l2_factor = 1.2798e-04
# --- response to true image ---
# contribution of the leaky-relu network = 360.644806
# contribution of the FoE network = 60.087975
# contribution of the l2-term = 3.606831
# --- response to FBP ---
# contribution of the leaky-relu network = 505.635315
# contribution of the FoE network = 69.555153
# contribution of the l2-term = 3.973903
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1840/2250], avg_loss: -110.39707870, avg_gp_loss: 12.67946088, avg_diff: -173.79438171
# l2_factor = 1.2803e-04
# --- response to true image ---
# contribution of the leaky-relu network = 428.816101
# contribution of the FoE network = 77.367996
# contribution of the l2-term = 4.867739
# --- response to FBP ---
# contribution of the leaky-relu network = 614.692871
# contribution of the FoE network = 87.381027
# contribution of the l2-term = 5.354935
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1860/2250], avg_loss: -112.25328407, avg_gp_loss: 13.05619597, avg_diff: -177.53426514
# l2_factor = 1.2809e-04
# --- response to true image ---
# contribution of the leaky-relu network = 451.494232
# contribution of the FoE network = 84.923370
# contribution of the l2-term = 5.896012
# --- response to FBP ---
# contribution of the leaky-relu network = 618.533630
# contribution of the FoE network = 94.818558
# contribution of the l2-term = 6.409841
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1880/2250], avg_loss: -109.98544922, avg_gp_loss: 12.94994998, avg_diff: -174.73519897
# l2_factor = 1.2814e-04
# --- response to true image ---
# contribution of the leaky-relu network = 392.301453
# contribution of the FoE network = 77.541550
# contribution of the l2-term = 5.136794
# --- response to FBP ---
# contribution of the leaky-relu network = 549.891907
# contribution of the FoE network = 87.601471
# contribution of the l2-term = 5.610201
# ==================
# ----single convex AR----
# epoch: [1/10], mini-batch: [1900/2250], avg_loss: -107.15083618, avg_gp_loss: 12.35194073, avg_diff: -168.91053925
# l2_factor = 1.2819e-04
# --- response to true image ---
# contribution of the leaky-relu network = 336.912170
# contribution of the FoE network = 53.381981
# contribution of the l2-term = 2.832266
# --- response to FBP ---
# ...
# --- response to FBP ---
# contribution of the leaky-relu network = 650.017761
# contribution of the FoE network = 292.732574
# contribution of the l2-term = 5.762748
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1640/2250], avg_loss: -138.99249306, avg_gp_loss: 13.42231524, avg_diff: -206.10407104
# l2_factor = 1.9129e-04
# --- response to true image ---
# contribution of the leaky-relu network = 485.996155
# contribution of the FoE network = 190.887650
# contribution of the l2-term = 3.385934
# --- response to FBP ---
# contribution of the leaky-relu network = 656.743164
# contribution of the FoE network = 224.712479
# contribution of the l2-term = 3.833368
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1660/2250], avg_loss: -135.35447845, avg_gp_loss: 13.76368814, avg_diff: -204.17291870
# l2_factor = 1.9137e-04
# --- response to true image ---
# contribution of the leaky-relu network = 518.522888
# contribution of the FoE network = 323.227051
# contribution of the l2-term = 6.473241
# --- response to FBP ---
# contribution of the leaky-relu network = 693.820007
# contribution of the FoE network = 354.592987
# contribution of the l2-term = 7.154987
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1680/2250], avg_loss: -138.66229591, avg_gp_loss: 14.08990421, avg_diff: -209.11181946
# l2_factor = 1.9145e-04
# --- response to true image ---
# contribution of the leaky-relu network = 409.304626
# contribution of the FoE network = 157.573151
# contribution of the l2-term = 1.957593
# --- response to FBP ---
# contribution of the leaky-relu network = 560.374512
# contribution of the FoE network = 188.640732
# contribution of the l2-term = 2.395253
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1700/2250], avg_loss: -131.82458649, avg_gp_loss: 12.68089881, avg_diff: -195.22908020
# l2_factor = 1.9152e-04
# --- response to true image ---
# contribution of the leaky-relu network = 517.479675
# contribution of the FoE network = 306.726471
# contribution of the l2-term = 6.037658
# --- response to FBP ---
# contribution of the leaky-relu network = 681.268982
# contribution of the FoE network = 337.242737
# contribution of the l2-term = 6.677340
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1720/2250], avg_loss: -134.92685966, avg_gp_loss: 13.28060365, avg_diff: -201.32987671
# l2_factor = 1.9160e-04
# --- response to true image ---
# contribution of the leaky-relu network = 513.843323
# contribution of the FoE network = 257.610016
# contribution of the l2-term = 5.006642
# --- response to FBP ---
# contribution of the leaky-relu network = 670.519958
# contribution of the FoE network = 288.117432
# contribution of the l2-term = 5.539901
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1740/2250], avg_loss: -130.40458488, avg_gp_loss: 12.43959656, avg_diff: -192.60256653
# l2_factor = 1.9168e-04
# --- response to true image ---
# contribution of the leaky-relu network = 483.508759
# contribution of the FoE network = 221.972504
# contribution of the l2-term = 3.873334
# --- response to FBP ---
# contribution of the leaky-relu network = 656.262146
# contribution of the FoE network = 255.363266
# contribution of the l2-term = 4.366871
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1760/2250], avg_loss: -137.65601807, avg_gp_loss: 13.49542894, avg_diff: -205.13316040
# l2_factor = 1.9175e-04
# --- response to true image ---
# contribution of the leaky-relu network = 573.722351
# contribution of the FoE network = 356.882477
# contribution of the l2-term = 8.220041
# --- response to FBP ---
# contribution of the leaky-relu network = 754.809631
# contribution of the FoE network = 389.137360
# contribution of the l2-term = 8.945042
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1780/2250], avg_loss: -132.88255348, avg_gp_loss: 13.10445962, avg_diff: -198.40485229
# l2_factor = 1.9183e-04
# --- response to true image ---
# contribution of the leaky-relu network = 491.220581
# contribution of the FoE network = 239.308762
# contribution of the l2-term = 4.139728
# --- response to FBP ---
# contribution of the leaky-relu network = 659.374512
# contribution of the FoE network = 271.907379
# contribution of the l2-term = 4.663479
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1800/2250], avg_loss: -136.42564430, avg_gp_loss: 13.48735452, avg_diff: -203.86241608
# l2_factor = 1.9191e-04
# --- response to true image ---
# contribution of the leaky-relu network = 436.401215
# contribution of the FoE network = 171.595810
# contribution of the l2-term = 1.772687
# --- response to FBP ---
# contribution of the leaky-relu network = 618.694763
# contribution of the FoE network = 200.181488
# contribution of the l2-term = 2.244110
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1820/2250], avg_loss: -137.86619530, avg_gp_loss: 13.68913436, avg_diff: -206.31186523
# l2_factor = 1.9198e-04
# --- response to true image ---
# contribution of the leaky-relu network = 481.153900
# contribution of the FoE network = 216.007935
# contribution of the l2-term = 3.877999
# --- response to FBP ---
# contribution of the leaky-relu network = 644.938538
# contribution of the FoE network = 247.992294
# contribution of the l2-term = 4.359345
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1840/2250], avg_loss: -134.92277031, avg_gp_loss: 13.60595498, avg_diff: -202.95254517
# l2_factor = 1.9206e-04
# --- response to true image ---
# contribution of the leaky-relu network = 457.966431
# contribution of the FoE network = 246.217972
# contribution of the l2-term = 4.760853
# --- response to FBP ---
# contribution of the leaky-relu network = 609.047363
# contribution of the FoE network = 279.805908
# contribution of the l2-term = 5.282798
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1860/2250], avg_loss: -140.38059158, avg_gp_loss: 13.95928173, avg_diff: -210.17699890
# l2_factor = 1.9214e-04
# --- response to true image ---
# contribution of the leaky-relu network = 504.208282
# contribution of the FoE network = 287.811127
# contribution of the l2-term = 5.651597
# --- response to FBP ---
# contribution of the leaky-relu network = 680.986450
# contribution of the FoE network = 320.684631
# contribution of the l2-term = 6.250686
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1880/2250], avg_loss: -131.72569962, avg_gp_loss: 12.45892687, avg_diff: -194.02033386
# l2_factor = 1.9222e-04
# --- response to true image ---
# contribution of the leaky-relu network = 492.658386
# contribution of the FoE network = 209.846878
# contribution of the l2-term = 3.610758
# --- response to FBP ---
# contribution of the leaky-relu network = 669.192749
# contribution of the FoE network = 243.223129
# contribution of the l2-term = 4.084089
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1900/2250], avg_loss: -133.82421341, avg_gp_loss: 13.51822808, avg_diff: -201.41535339
# l2_factor = 1.9229e-04
# --- response to true image ---
# contribution of the leaky-relu network = 449.203979
# contribution of the FoE network = 224.306870
# contribution of the l2-term = 4.103406
# --- response to FBP ---
# contribution of the leaky-relu network = 603.746826
# contribution of the FoE network = 258.127777
# contribution of the l2-term = 4.592467
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1920/2250], avg_loss: -135.87369576, avg_gp_loss: 13.30080390, avg_diff: -202.37771606
# l2_factor = 1.9237e-04
# --- response to true image ---
# contribution of the leaky-relu network = 515.206787
# contribution of the FoE network = 296.397125
# contribution of the l2-term = 5.497114
# --- response to FBP ---
# contribution of the leaky-relu network = 691.241089
# contribution of the FoE network = 326.994659
# contribution of the l2-term = 6.122150
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1940/2250], avg_loss: -134.38323174, avg_gp_loss: 13.32195039, avg_diff: -200.99298401
# l2_factor = 1.9245e-04
# --- response to true image ---
# contribution of the leaky-relu network = 501.408295
# contribution of the FoE network = 267.546875
# contribution of the l2-term = 5.363981
# --- response to FBP ---
# contribution of the leaky-relu network = 651.919250
# contribution of the FoE network = 298.265717
# contribution of the l2-term = 5.912822
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1960/2250], avg_loss: -131.72938118, avg_gp_loss: 12.73921013, avg_diff: -195.42543030
# l2_factor = 1.9252e-04
# --- response to true image ---
# contribution of the leaky-relu network = 483.045380
# contribution of the FoE network = 266.144684
# contribution of the l2-term = 5.385400
# --- response to FBP ---
# contribution of the leaky-relu network = 640.845825
# contribution of the FoE network = 299.327301
# contribution of the l2-term = 5.949102
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [1980/2250], avg_loss: -135.70123711, avg_gp_loss: 13.31053634, avg_diff: -202.25391846
# l2_factor = 1.9260e-04
# --- response to true image ---
# contribution of the leaky-relu network = 462.531891
# contribution of the FoE network = 205.749084
# contribution of the l2-term = 3.510878
# --- response to FBP ---
# contribution of the leaky-relu network = 617.625122
# contribution of the FoE network = 237.191391
# contribution of the l2-term = 3.980341
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2000/2250], avg_loss: -139.95096855, avg_gp_loss: 13.64769506, avg_diff: -208.18944397
# l2_factor = 1.9268e-04
# --- response to true image ---
# contribution of the leaky-relu network = 538.152649
# contribution of the FoE network = 242.428650
# contribution of the l2-term = 4.325365
# --- response to FBP ---
# contribution of the leaky-relu network = 743.329895
# contribution of the FoE network = 275.234619
# contribution of the l2-term = 4.856998
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2020/2250], avg_loss: -132.67872200, avg_gp_loss: 13.42881899, avg_diff: -199.82281799
# l2_factor = 1.9275e-04
# --- response to true image ---
# contribution of the leaky-relu network = 449.799530
# contribution of the FoE network = 192.055801
# contribution of the l2-term = 2.114072
# --- response to FBP ---
# contribution of the leaky-relu network = 633.284424
# contribution of the FoE network = 219.975433
# contribution of the l2-term = 2.616899
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2040/2250], avg_loss: -138.46468506, avg_gp_loss: 13.77806511, avg_diff: -207.35501099
# l2_factor = 1.9283e-04
# --- response to true image ---
# contribution of the leaky-relu network = 520.083313
# contribution of the FoE network = 329.563934
# contribution of the l2-term = 7.122431
# --- response to FBP ---
# contribution of the leaky-relu network = 693.873596
# contribution of the FoE network = 362.553070
# contribution of the l2-term = 7.805042
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2060/2250], avg_loss: -135.54578590, avg_gp_loss: 13.39794297, avg_diff: -202.53550110
# l2_factor = 1.9291e-04
# --- response to true image ---
# contribution of the leaky-relu network = 527.095459
# contribution of the FoE network = 334.479279
# contribution of the l2-term = 6.535851
# --- response to FBP ---
# contribution of the leaky-relu network = 696.201599
# contribution of the FoE network = 365.751984
# contribution of the l2-term = 7.234075
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2080/2250], avg_loss: -138.30183487, avg_gp_loss: 13.79981189, avg_diff: -207.30089417
# l2_factor = 1.9299e-04
# --- response to true image ---
# contribution of the leaky-relu network = 473.896759
# contribution of the FoE network = 224.803635
# contribution of the l2-term = 4.104827
# --- response to FBP ---
# contribution of the leaky-relu network = 639.379272
# contribution of the FoE network = 259.013428
# contribution of the l2-term = 4.601960
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2100/2250], avg_loss: -137.26300888, avg_gp_loss: 13.57812405, avg_diff: -205.15362854
# l2_factor = 1.9306e-04
# --- response to true image ---
# contribution of the leaky-relu network = 486.485687
# contribution of the FoE network = 257.082550
# contribution of the l2-term = 4.721362
# --- response to FBP ---
# contribution of the leaky-relu network = 656.707336
# contribution of the FoE network = 289.910889
# contribution of the l2-term = 5.274972
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2120/2250], avg_loss: -134.14031982, avg_gp_loss: 13.25283670, avg_diff: -200.40450439
# l2_factor = 1.9314e-04
# --- response to true image ---
# contribution of the leaky-relu network = 452.125275
# contribution of the FoE network = 191.272934
# contribution of the l2-term = 2.864661
# --- response to FBP ---
# contribution of the leaky-relu network = 610.733521
# contribution of the FoE network = 222.804550
# contribution of the l2-term = 3.334109
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2140/2250], avg_loss: -139.39150543, avg_gp_loss: 13.73927364, avg_diff: -208.08787537
# l2_factor = 1.9322e-04
# --- response to true image ---
# contribution of the leaky-relu network = 527.425110
# contribution of the FoE network = 280.666840
# contribution of the l2-term = 5.410092
# --- response to FBP ---
# contribution of the leaky-relu network = 702.706909
# contribution of the FoE network = 312.478119
# contribution of the l2-term = 5.992761
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2160/2250], avg_loss: -135.59217796, avg_gp_loss: 13.48023338, avg_diff: -202.99334412
# l2_factor = 1.9330e-04
# --- response to true image ---
# contribution of the leaky-relu network = 468.792572
# contribution of the FoE network = 206.043869
# contribution of the l2-term = 3.751611
# --- response to FBP ---
# contribution of the leaky-relu network = 625.487854
# contribution of the FoE network = 240.218979
# contribution of the l2-term = 4.211357
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2180/2250], avg_loss: -134.29064560, avg_gp_loss: 13.01458166, avg_diff: -199.36355286
# l2_factor = 1.9337e-04
# --- response to true image ---
# contribution of the leaky-relu network = 542.545105
# contribution of the FoE network = 321.585297
# contribution of the l2-term = 6.397254
# --- response to FBP ---
# contribution of the leaky-relu network = 718.594849
# contribution of the FoE network = 353.383392
# contribution of the l2-term = 7.067547
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2200/2250], avg_loss: -139.21606178, avg_gp_loss: 13.99307961, avg_diff: -209.18146057
# l2_factor = 1.9345e-04
# --- response to true image ---
# contribution of the leaky-relu network = 535.580566
# contribution of the FoE network = 291.608734
# contribution of the l2-term = 5.468518
# --- response to FBP ---
# contribution of the leaky-relu network = 713.044922
# contribution of the FoE network = 323.041809
# contribution of the l2-term = 6.083181
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2220/2250], avg_loss: -135.76921768, avg_gp_loss: 13.19124727, avg_diff: -201.72545471
# l2_factor = 1.9353e-04
# --- response to true image ---
# contribution of the leaky-relu network = 497.753723
# contribution of the FoE network = 224.984451
# contribution of the l2-term = 4.249196
# --- response to FBP ---
# contribution of the leaky-relu network = 660.787842
# contribution of the FoE network = 256.026733
# contribution of the l2-term = 4.748582
# ==================
# ----single convex AR----
# epoch: [10/10], mini-batch: [2240/2250], avg_loss: -137.66082535, avg_gp_loss: 13.50381832, avg_diff: -205.17991943
# l2_factor = 1.9361e-04
# --- response to true image ---
# contribution of the leaky-relu network = 572.987549
# contribution of the FoE network = 334.226654
# contribution of the l2-term = 6.742682
# --- response to FBP ---
# contribution of the leaky-relu network = 777.204834
# contribution of the FoE network = 366.231689
# contribution of the l2-term = 7.448281

# %%
#save the models 
pretrained_network_path = './ver2_pretrained_nets/'
os.makedirs(pretrained_network_path, exist_ok=True)
# torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
# torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
# torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_" + 'epoch_%02d'%epoch + ".pt") 

torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_paired.pt") 
torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_paired.pt") 
torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_paired.pt")

# %%
import matplotlib.pyplot as plt
pretrained_network_path = './ver2_pretrained_nets/'

avg_loss_acr_paired_arr = np.array(avg_loss_acr_paired, dtype=np.float32)
avg_loss_acr_unpaired_arr = np.load(pretrained_network_path + "avg_loss_acr_unpaired_arr.npy")
np.save(pretrained_network_path + "avg_loss_acr_paired_arr.npy", avg_loss_acr_paired_arr)
train_steps = np.arange(1, 1+avg_loss_acr_paired_arr.size)

# plt.plot(train_steps, avg_loss_acr_paired_arr, 'r', train_steps, avg_loss_acr_unpaired_arr, 'b', linewidth=2.0)
# plt.legend(['paired', 'unpaired'], fontsize=24.0)


#plt.plot(train_steps, avg_loss_acr_paired_arr, 'r', linewidth=2.0)

plt.plot(train_steps, avg_loss_acr_unpaired_arr, 'b', linewidth=2.0)

plt.gcf().set_size_inches(11.0,8.0)
plt.xlabel('training steps', fontsize=28.0)
plt.ylabel('training loss', fontsize=28.0)
plt.tick_params(axis='both', which='major', labelsize=24.0)
plt.grid()

plt.savefig(pretrained_network_path + 'unpaired_train.png', bbox_inches='tight', transparent = False, pad_inches=0.1)
#plt.savefig(pretrained_network_path + 'paired_vs_unpaired_train_combined.png', bbox_inches='tight', transparent = False, pad_inches=0.1)
#plt.savefig(pretrained_network_path + 'paired_train.png', bbox_inches='tight', transparent = False, pad_inches=0.1)

plt.show()

# %%
avg_loss_acr_unpaired_arr.shape
# Out:
# (1120,)

# %%
#check convexity of the net
n_trials = 50
convexity = 0
for trial in np.arange(n_trials):
    x1 = torch.rand(dummy_input.size()).to(device)
    x2 = torch.rand(dummy_input.size()).to(device)
    alpha = torch.rand(1).to(device)

    cvx_combo_of_input = acr(alpha * x1 + (1-alpha)*x2)
    cvx_combo_of_output = alpha * acr(x1) + (1-alpha)*acr(x2)

    convexity += (cvx_combo_of_input.mean() <= cvx_combo_of_output.mean())
if(convexity == n_trials):
    print('the net is %s'%'convex') 
else:
    print('the net is %s'%'non-convex')
# Out:
# the net is convex

# %%
# Out:
# l2_factor = 2.4154e-04
