# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torch.utils.data import Dataset
from IPython.display import Image
import numpy as np
import os
import glob
import random
from PIL import Image
from torch.utils.tensorboard import SummaryWriter
import torchvision.utils as vutils
from skimage.measure import compare_ssim, compare_psnr


#writer = SummaryWriter()
import warnings
warnings.filterwarnings(action='once')


device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device = %s'%device)
print('torch version = %s'%(torch.__version__))
print('no. of GPUs = %d'%(torch.cuda.device_count()))

batch_size, n_in_channels, img_size = 1, 1, 28 #for toy problem
val_batch_size = 1
#dataloader

from torch.utils.data import DataLoader

#custom dataset class 
class ImageDataset(Dataset):
    def __init__(self, root, transforms_= None, unaligned = True, mode = 'train'):
        self.transform = transforms.Compose(transforms_)
        self.unaligned = unaligned
        
        self.files = sorted(glob.glob(os.path.join(root, '%s/groundtruth'% mode) + '/*.*'))


    def __getitem__(self, index):
        if self.unaligned:
            ground_truth = self.transform(Image.fromarray(np.load(self.files[random.randint(0, len(self.files) - 1)])))
        else:
            ground_truth = self.transform(Image.fromarray(np.load(self.files[index % len(self.files)])))
        
        

        return {'ground_truth': ground_truth}

    def __len__(self):
        return len(self.files)
    
transform_train_and_test = [transforms.ToTensor()]
datapath = '../data/MNIST'

#training dataloader: test the performance for unaligned=False, i.e. for aligned/paired data
train_dataloader = DataLoader(ImageDataset(datapath, transforms_=transform_train_and_test, unaligned=False, mode = 'train'),\
                              batch_size = batch_size, shuffle = True) #the samples must be unaligned and shuffled
print('number of minibatches during training = %d'%len(train_dataloader))

#modified sigmoid 
def modified_sigmoid(x, alpha):
    x = 1 + torch.exp(-alpha*x)
    x = torch.div(torch.ones(x.size()).to(device), x)
    return x
# Out:
# device = cpu
# torch version = 1.8.0
# no. of GPUs = 0
# number of minibatches during training = 500
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#build a convex discriminator (for 10 x 10 inputs)
n_filters = 5 #was 48 previously
filt_dim = 5
n_layers = 10

class icnn_new_model(nn.Module):
    def __init__(self, n_in_channels=1, n_filters=n_filters, filt_dim=filt_dim, n_layers=n_layers):
        super(icnn_new_model, self).__init__()
        
        self.n_layers = n_layers
        #these layers should have non-negative weights
        self.wz = nn.ModuleList([nn.Conv2d(n_filters, n_filters, kernel_size=filt_dim, stride=1, padding=2, bias=False) for i in range(self.n_layers)])
        
        #these layers can have arbitrary weights
        self.wx = nn.ModuleList([nn.Conv2d(n_in_channels, n_filters, kernel_size=filt_dim, stride=1, padding=2, bias=True) for i in range(self.n_layers+1)])
        
        #one final conv layer with nonnegative weights
        self.final_conv2d = nn.Conv2d(n_filters, 1, kernel_size=filt_dim, stride=1, padding=2, bias=False)
        
        #slope of leaky-relu
        self.negative_slope = 0.2 
        
    def forward(self, x):
        z = F.leaky_relu(self.wx[0](x), negative_slope=self.negative_slope)
        for layer in range(self.n_layers):
            z = F.leaky_relu(self.wz[layer](z) + self.wx[layer+1](x), negative_slope=self.negative_slope)
        z = self.final_conv2d(z)
        z_avg = F.avg_pool2d(z, z.size()[2:]).view(z.size()[0], -1)
        
        return z_avg
    

#realize the model: just one net which outputs a small number for true and large for something noisy 
mye = icnn_new_model().to(device) 


#manually initialize weights
#the following are initialized with non-negative weights
def initialize_weights(net, n_layers = n_layers, min_val = 0.0, max_val = 0.001):
    for layer in range(n_layers):
        net.wz[layer].weight.data = min_val + (max_val - min_val) * torch.rand(n_filters,n_filters,filt_dim,filt_dim).to(device)
    
    net.final_conv2d.weight.data = min_val + (max_val - min_val) * torch.rand(1,n_filters,filt_dim,filt_dim).to(device)
    return net

mye = initialize_weights(mye)

#for debugging
dummy_input = torch.rand(batch_size, n_in_channels, img_size, img_size).to(device)
mye_output = mye(dummy_input)
print(mye_output.size())

total_params = sum(p.numel() for p in mye.parameters())
print('total number of parameters in MYE = %d'%total_params)
# Out:
# torch.Size([1, 1])
# total number of parameters in MYE = 7805
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###### FOR DEBUGGING ###### 

#check the contributions of each term in the ACR
noise_sd_for_training_stability = 0.0
for idx, batch in enumerate(train_dataloader):
    ############################################
    images = batch["ground_truth"].to(device) #true images
    batch_size = images.size()[0]

    #true images + slight noise for stability
    real_x = images + noise_sd_for_training_stability*torch.randn(batch_size,n_in_channels,img_size,img_size).to(device) 
    
    #for true image
    mye_output = mye(real_x)
    print('--- response to true image ---')
    print('contribution of the leaky-relu network = %.6f'%torch.sum(mye_output))
    
    break
# Out:
# --- response to true image ---
# contribution of the leaky-relu network = 0.002639

# %%
#non-negativity penalty
def clamp_weights(net, n_layers = n_layers): #set negative weights to 0
    for layer in range(n_layers):
        net.wz[layer].weight.data.clamp_(0)
    
    net.final_conv2d.weight.data.clamp_(0)
    return net

import torch.autograd as autograd
def compute_gradient(net, samples): 
    interpolates = (samples).requires_grad_(True)
    validity = net(interpolates)
    fake = Variable(torch.FloatTensor(np.ones(validity.shape)), requires_grad=False)
    # Get gradient w.r.t. interpolates
    gradients = autograd.grad(outputs=validity, inputs=interpolates,
                              grad_outputs=fake, create_graph=True, retain_graph=True,
                              only_inputs=True)[0]
    
    gradients = gradients.view(gradients.size(0), -1)
    
    return gradients

def compute_hessian_penalty():
    k=9

def compute_l1_mye_penalty(samples, gradient, alpha, lamb): # for a general regularizer, we can use a simular function
    # Compute l2 gradient norm loss
    gradient_penalty = 1./2 * (gradient.norm(2, dim=1) ** 2).mean() 
    # Compute prior loss, i.e., l1 loss
    samples = samples.view(samples.size(0),-1)
    prior_penalty = (samples - lamb * gradient).norm(1, dim=1).mean()
    
    loss = lamb**2 * gradient_penalty + lamb * alpha * prior_penalty

    return loss, lamb**2 * gradient_penalty, lamb * alpha * prior_penalty

# %%
###########
import itertools
betas = (0.5, 0.99) 

#trained without FoE
#optimizer_acr = torch.optim.Adam(itertools.chain(acr.parameters(),l2_net.parameters()), lr=2*1e-5, betas=betas, weight_decay=0.0)

# #when trained with FoE included
optimizer_mye = torch.optim.Adam(mye.parameters(), lr=2*1e-3, betas=betas, weight_decay=0.0)

# proximal map related variables
lamb = 1.
alpha = 1.

noise_sd_for_training_stability = 0.1
n_epochs = 10
num_minibatches = 20 #for display

avg_loss_mye_paired = []

for epoch in np.arange(n_epochs):
    
    #restart scheduler and reset losses
    scheduler_mye = torch.optim.lr_scheduler.StepLR(optimizer_mye, step_size=20, gamma=0.9)
    total_loss = 0.0
    total_gp_loss = 0.0
    total_pp_loss = 0.0
    
    for idx, batch in enumerate(train_dataloader):
        
        ############################################
        images = batch["ground_truth"].to(device) #true images
        batch_size = images.size()[0]
        
        #true images + slight noise for stability
        real_x = images + noise_sd_for_training_stability*torch.randn(batch_size,n_in_channels,img_size,img_size).to(device) 
        
        gradient = compute_gradient(mye,real_x)
        
        loss, gp_loss, pp_loss = compute_l1_mye_penalty(real_x, gradient, alpha, lamb)
        
        #parameter update
        optimizer_mye.zero_grad()
        loss.backward()
        optimizer_mye.step()
        
        total_loss += loss.item()
        total_gp_loss += gp_loss.item()
        total_pp_loss += pp_loss.item()
        
        #clamp negative weights to 0
        mye = clamp_weights(mye) 
        #take scheduler steps
        scheduler_mye.step()
        
        if(idx % num_minibatches == num_minibatches-1):
            ####### compute avg. loss over minibatches #######
            avg_loss = total_loss/num_minibatches
            avg_gp_loss = total_gp_loss/num_minibatches
            avg_pp_loss = total_pp_loss/num_minibatches
            
            avg_loss_mye_paired.append(avg_loss)
            
            #reset the losses
            total_loss = 0.0
            total_gp_loss = 0.0
            total_pp_loss = 0.0
            
            print('==================')
            print('----single convex MYE----')
            print("epoch: [{}/{}], mini-batch: [{}/{}], avg_loss: {:.8f}, avg_gp_loss: {:.8f}, avg_pp_loss: {:.8f}".\
                  format(epoch+1, n_epochs, idx+1, len(train_dataloader), avg_loss, avg_gp_loss, avg_pp_loss))
            
            print('--- response to true image ---')
            mye_output_true = mye(real_x)
            print('contribution of the leaky-relu network = %.6f'%torch.sum(mye_output_true))

#             mye_output_fbp = mye(fake_x)
#             print('--- response to FBP ---')
#             print('contribution of the leaky-relu network = %.6f'%torch.sum(acr_output_fbp))
#             print('contribution of the FoE network = %.6f'%torch.sum(foe_output_fbp))
#             print('contribution of the l2-term = %.6f'%torch.sum(l2_term_fbp))
    
            #save the models 
            pretrained_network_path = '../models/l1reg_pretrained_nets/'
            os.makedirs(pretrained_network_path, exist_ok=True)
#             torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
#             torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
#             torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_" + 'epoch_%02d'%epoch + ".pt") 

            torch.save(mye.state_dict(),  pretrained_network_path + "mye_new_model_foe_included_paired.pt")
# Out:
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [20/500], avg_loss: 140.30106277, avg_gp_loss: 33.69380641, avg_pp_loss: 106.60725784
# --- response to true image ---
# contribution of the leaky-relu network = 56.123554
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [40/500], avg_loss: 89.68311596, avg_gp_loss: 26.38152661, avg_pp_loss: 63.30158958
# --- response to true image ---
# contribution of the leaky-relu network = 21.131855
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [60/500], avg_loss: 89.48350143, avg_gp_loss: 26.63508425, avg_pp_loss: 62.84841671
# --- response to true image ---
# contribution of the leaky-relu network = 51.041401
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [80/500], avg_loss: 90.72659874, avg_gp_loss: 26.54627671, avg_pp_loss: 64.18032150
# --- response to true image ---
# contribution of the leaky-relu network = 23.199310
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [100/500], avg_loss: 84.27623215, avg_gp_loss: 24.50749102, avg_pp_loss: 59.76874046
# --- response to true image ---
# contribution of the leaky-relu network = 32.866783
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [120/500], avg_loss: 87.71831779, avg_gp_loss: 28.09307852, avg_pp_loss: 59.62523937
# --- response to true image ---
# contribution of the leaky-relu network = 32.293018
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [140/500], avg_loss: 91.85920715, avg_gp_loss: 28.26407471, avg_pp_loss: 63.59513302
# --- response to true image ---
# contribution of the leaky-relu network = 49.071365
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [160/500], avg_loss: 86.20622749, avg_gp_loss: 26.66794677, avg_pp_loss: 59.53828049
# --- response to true image ---
# contribution of the leaky-relu network = 60.211552
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [180/500], avg_loss: 87.20359116, avg_gp_loss: 27.85457783, avg_pp_loss: 59.34901428
# --- response to true image ---
# contribution of the leaky-relu network = 49.147709
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [200/500], avg_loss: 80.86432419, avg_gp_loss: 25.72708302, avg_pp_loss: 55.13724174
# --- response to true image ---
# contribution of the leaky-relu network = 46.077408
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [220/500], avg_loss: 79.68971672, avg_gp_loss: 25.77713017, avg_pp_loss: 53.91258602
# --- response to true image ---
# contribution of the leaky-relu network = 60.877712
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [240/500], avg_loss: 81.67939453, avg_gp_loss: 27.24298029, avg_pp_loss: 54.43641357
# --- response to true image ---
# contribution of the leaky-relu network = 46.081760
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [260/500], avg_loss: 86.86340733, avg_gp_loss: 31.24828391, avg_pp_loss: 55.61512375
# --- response to true image ---
# contribution of the leaky-relu network = 47.989708
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [280/500], avg_loss: 78.80298100, avg_gp_loss: 27.45725260, avg_pp_loss: 51.34572849
# --- response to true image ---
# contribution of the leaky-relu network = 40.793888
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [300/500], avg_loss: 83.48764668, avg_gp_loss: 29.67863894, avg_pp_loss: 53.80900745
# --- response to true image ---
# contribution of the leaky-relu network = 51.972313
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [320/500], avg_loss: 81.12997417, avg_gp_loss: 27.40866051, avg_pp_loss: 53.72131329
# --- response to true image ---
# contribution of the leaky-relu network = 29.591217
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [340/500], avg_loss: 88.08308620, avg_gp_loss: 31.10791893, avg_pp_loss: 56.97516785
# --- response to true image ---
# contribution of the leaky-relu network = 40.615799
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [360/500], avg_loss: 81.89620514, avg_gp_loss: 28.37147818, avg_pp_loss: 53.52472668
# --- response to true image ---
# contribution of the leaky-relu network = 74.691460
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [380/500], avg_loss: 77.11607533, avg_gp_loss: 26.71999402, avg_pp_loss: 50.39608212
# --- response to true image ---
# contribution of the leaky-relu network = 58.304607
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [400/500], avg_loss: 80.13880939, avg_gp_loss: 28.51057158, avg_pp_loss: 51.62823772
# --- response to true image ---
# contribution of the leaky-relu network = 32.068420
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [420/500], avg_loss: 83.35970116, avg_gp_loss: 29.65007267, avg_pp_loss: 53.70962849
# --- response to true image ---
# contribution of the leaky-relu network = 40.210331
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [440/500], avg_loss: 76.55310440, avg_gp_loss: 25.87785573, avg_pp_loss: 50.67524929
# --- response to true image ---
# contribution of the leaky-relu network = 40.265034
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [460/500], avg_loss: 90.38448410, avg_gp_loss: 33.44006510, avg_pp_loss: 56.94441853
# --- response to true image ---
# contribution of the leaky-relu network = 63.675037
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [480/500], avg_loss: 78.99331741, avg_gp_loss: 27.54336462, avg_pp_loss: 51.44995308
# --- response to true image ---
# contribution of the leaky-relu network = 61.691322
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [500/500], avg_loss: 79.24134159, avg_gp_loss: 28.40737953, avg_pp_loss: 50.83396225
# --- response to true image ---
# contribution of the leaky-relu network = 62.098190
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [20/500], avg_loss: 76.19481621, avg_gp_loss: 26.64582796, avg_pp_loss: 49.54898872
# --- response to true image ---
# contribution of the leaky-relu network = 45.092232
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [40/500], avg_loss: 84.06663647, avg_gp_loss: 30.63355370, avg_pp_loss: 53.43308258
# --- response to true image ---
# contribution of the leaky-relu network = 51.427635
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [60/500], avg_loss: 75.94453545, avg_gp_loss: 26.55369453, avg_pp_loss: 49.39083958
# --- response to true image ---
# contribution of the leaky-relu network = 46.164757
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [80/500], avg_loss: 79.99038582, avg_gp_loss: 28.92905264, avg_pp_loss: 51.06133270
# --- response to true image ---
# contribution of the leaky-relu network = 56.717823
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [100/500], avg_loss: 79.15194721, avg_gp_loss: 28.62753611, avg_pp_loss: 50.52441101
# --- response to true image ---
# contribution of the leaky-relu network = 72.437973
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [120/500], avg_loss: 73.60461979, avg_gp_loss: 25.73313017, avg_pp_loss: 47.87148972
# --- response to true image ---
# contribution of the leaky-relu network = 32.014839
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [140/500], avg_loss: 81.24969883, avg_gp_loss: 29.79350185, avg_pp_loss: 51.45619678
# --- response to true image ---
# contribution of the leaky-relu network = 46.585899
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [160/500], avg_loss: 77.43156586, avg_gp_loss: 27.76035433, avg_pp_loss: 49.67121086
# --- response to true image ---
# contribution of the leaky-relu network = 43.461781
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [180/500], avg_loss: 81.94560623, avg_gp_loss: 29.10921144, avg_pp_loss: 52.83639469
# --- response to true image ---
# contribution of the leaky-relu network = 76.575500
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [200/500], avg_loss: 85.78905334, avg_gp_loss: 31.26866732, avg_pp_loss: 54.52038612
# --- response to true image ---
# contribution of the leaky-relu network = 56.048100
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [220/500], avg_loss: 84.91582623, avg_gp_loss: 31.70606785, avg_pp_loss: 53.20975819
# --- response to true image ---
# contribution of the leaky-relu network = 57.324078
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [240/500], avg_loss: 84.69418526, avg_gp_loss: 30.93562489, avg_pp_loss: 53.75855885
# --- response to true image ---
# contribution of the leaky-relu network = 64.039360
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [260/500], avg_loss: 78.72633762, avg_gp_loss: 27.81526051, avg_pp_loss: 50.91107788
# --- response to true image ---
# contribution of the leaky-relu network = 53.929749
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [280/500], avg_loss: 78.51560898, avg_gp_loss: 28.39363379, avg_pp_loss: 50.12197571
# --- response to true image ---
# contribution of the leaky-relu network = 46.931431
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [300/500], avg_loss: 81.02989140, avg_gp_loss: 29.06092634, avg_pp_loss: 51.96896572
# --- response to true image ---
# contribution of the leaky-relu network = 67.457222
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [320/500], avg_loss: 83.80577965, avg_gp_loss: 30.24756742, avg_pp_loss: 53.55821171
# --- response to true image ---
# contribution of the leaky-relu network = 58.406509
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [340/500], avg_loss: 84.53763294, avg_gp_loss: 30.32268314, avg_pp_loss: 54.21494884
# --- response to true image ---
# contribution of the leaky-relu network = 52.833843
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [360/500], avg_loss: 76.35615292, avg_gp_loss: 27.64000273, avg_pp_loss: 48.71614914
# --- response to true image ---
# contribution of the leaky-relu network = 39.686974
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [380/500], avg_loss: 78.95472012, avg_gp_loss: 27.49040427, avg_pp_loss: 51.46431522
# --- response to true image ---
# contribution of the leaky-relu network = 53.413570
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [400/500], avg_loss: 77.13203220, avg_gp_loss: 27.00549879, avg_pp_loss: 50.12653332
# --- response to true image ---
# contribution of the leaky-relu network = 45.686707
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [420/500], avg_loss: 76.69710636, avg_gp_loss: 27.41497927, avg_pp_loss: 49.28212700
# --- response to true image ---
# contribution of the leaky-relu network = 73.379845
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [440/500], avg_loss: 78.14543571, avg_gp_loss: 27.20573249, avg_pp_loss: 50.93970280
# --- response to true image ---
# contribution of the leaky-relu network = 29.074999
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [460/500], avg_loss: 81.82614193, avg_gp_loss: 29.45249939, avg_pp_loss: 52.37364159
# --- response to true image ---
# contribution of the leaky-relu network = 56.518520
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [480/500], avg_loss: 84.88910713, avg_gp_loss: 31.02317953, avg_pp_loss: 53.86592751
# --- response to true image ---
# contribution of the leaky-relu network = 66.257057
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [500/500], avg_loss: 80.88522472, avg_gp_loss: 29.51606150, avg_pp_loss: 51.36916294
# --- response to true image ---
# contribution of the leaky-relu network = 68.916008
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [20/500], avg_loss: 83.30884399, avg_gp_loss: 30.18694057, avg_pp_loss: 53.12190418
# --- response to true image ---
# contribution of the leaky-relu network = 51.993958
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [40/500], avg_loss: 81.04327049, avg_gp_loss: 29.87592897, avg_pp_loss: 51.16734123
# --- response to true image ---
# contribution of the leaky-relu network = 56.480846
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [60/500], avg_loss: 78.73203812, avg_gp_loss: 28.52037048, avg_pp_loss: 50.21166763
# --- response to true image ---
# contribution of the leaky-relu network = 43.981052
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [80/500], avg_loss: 76.57243958, avg_gp_loss: 26.58527641, avg_pp_loss: 49.98716316
# --- response to true image ---
# contribution of the leaky-relu network = 32.275352
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [100/500], avg_loss: 83.11148777, avg_gp_loss: 29.61198807, avg_pp_loss: 53.49950066
# --- response to true image ---
# contribution of the leaky-relu network = 71.034111
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [120/500], avg_loss: 78.11219139, avg_gp_loss: 29.10450668, avg_pp_loss: 49.00768509
# --- response to true image ---
# contribution of the leaky-relu network = 50.293785
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [140/500], avg_loss: 83.87487221, avg_gp_loss: 30.93398504, avg_pp_loss: 52.94088669
# --- response to true image ---
# contribution of the leaky-relu network = 58.721424
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [160/500], avg_loss: 81.41371422, avg_gp_loss: 30.17190924, avg_pp_loss: 51.24180489
# --- response to true image ---
# contribution of the leaky-relu network = 34.757263
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [180/500], avg_loss: 78.62609177, avg_gp_loss: 29.43756351, avg_pp_loss: 49.18852787
# --- response to true image ---
# contribution of the leaky-relu network = 52.866222
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [200/500], avg_loss: 80.67073593, avg_gp_loss: 28.94776335, avg_pp_loss: 51.72297153
# --- response to true image ---
# contribution of the leaky-relu network = 66.547211
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [220/500], avg_loss: 79.98463478, avg_gp_loss: 28.94492722, avg_pp_loss: 51.03970776
# --- response to true image ---
# contribution of the leaky-relu network = 48.308578
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [240/500], avg_loss: 78.23507862, avg_gp_loss: 28.61387444, avg_pp_loss: 49.62120419
# --- response to true image ---
# contribution of the leaky-relu network = 73.124016
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [260/500], avg_loss: 77.46968060, avg_gp_loss: 27.51196265, avg_pp_loss: 49.95771885
# --- response to true image ---
# contribution of the leaky-relu network = 72.134026
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [280/500], avg_loss: 76.49121418, avg_gp_loss: 27.16928577, avg_pp_loss: 49.32192860
# --- response to true image ---
# contribution of the leaky-relu network = 51.421078
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [300/500], avg_loss: 80.03495426, avg_gp_loss: 28.66052537, avg_pp_loss: 51.37442837
# --- response to true image ---
# contribution of the leaky-relu network = 58.534576
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [320/500], avg_loss: 74.34781284, avg_gp_loss: 26.82195392, avg_pp_loss: 47.52585888
# --- response to true image ---
# contribution of the leaky-relu network = 57.988617
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [340/500], avg_loss: 79.63222504, avg_gp_loss: 29.05867977, avg_pp_loss: 50.57354527
# --- response to true image ---
# contribution of the leaky-relu network = 32.426971
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [360/500], avg_loss: 80.83356438, avg_gp_loss: 29.04312897, avg_pp_loss: 51.79043522
# --- response to true image ---
# contribution of the leaky-relu network = 41.765202
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [380/500], avg_loss: 80.59630260, avg_gp_loss: 29.12725339, avg_pp_loss: 51.46904907
# --- response to true image ---
# contribution of the leaky-relu network = 62.869610
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [400/500], avg_loss: 79.50974369, avg_gp_loss: 28.87899342, avg_pp_loss: 50.63075180
# --- response to true image ---
# contribution of the leaky-relu network = 75.647713
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [420/500], avg_loss: 82.70274620, avg_gp_loss: 29.35377665, avg_pp_loss: 53.34896984
# --- response to true image ---
# contribution of the leaky-relu network = 35.028912
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [440/500], avg_loss: 85.77035332, avg_gp_loss: 30.86108208, avg_pp_loss: 54.90927200
# --- response to true image ---
# contribution of the leaky-relu network = 48.489815
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [460/500], avg_loss: 80.14442692, avg_gp_loss: 28.65750303, avg_pp_loss: 51.48692436
# --- response to true image ---
# contribution of the leaky-relu network = 52.286018
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [480/500], avg_loss: 80.10982895, avg_gp_loss: 29.07599869, avg_pp_loss: 51.03382931
# --- response to true image ---
# contribution of the leaky-relu network = 48.617729
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [500/500], avg_loss: 80.31516933, avg_gp_loss: 29.94531174, avg_pp_loss: 50.36985760
# --- response to true image ---
# contribution of the leaky-relu network = 43.737503
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [20/500], avg_loss: 82.84542542, avg_gp_loss: 29.72590380, avg_pp_loss: 53.11952171
# --- response to true image ---
# contribution of the leaky-relu network = 85.013344
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [40/500], avg_loss: 76.54963913, avg_gp_loss: 29.01777983, avg_pp_loss: 47.53185978
# --- response to true image ---
# contribution of the leaky-relu network = 58.261639
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [60/500], avg_loss: 78.32483196, avg_gp_loss: 28.41805143, avg_pp_loss: 49.90678024
# --- response to true image ---
# contribution of the leaky-relu network = 58.273499
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [80/500], avg_loss: 77.65087852, avg_gp_loss: 29.39347038, avg_pp_loss: 48.25740891
# --- response to true image ---
# contribution of the leaky-relu network = 45.199982
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [100/500], avg_loss: 81.91417160, avg_gp_loss: 28.63681488, avg_pp_loss: 53.27735615
# --- response to true image ---
# contribution of the leaky-relu network = 49.669941
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [120/500], avg_loss: 82.85333633, avg_gp_loss: 30.22586298, avg_pp_loss: 52.62747307
# --- response to true image ---
# contribution of the leaky-relu network = 44.835011
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [140/500], avg_loss: 79.68028030, avg_gp_loss: 29.16719818, avg_pp_loss: 50.51308193
# --- response to true image ---
# contribution of the leaky-relu network = 49.577267
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [160/500], avg_loss: 80.78161736, avg_gp_loss: 29.43506174, avg_pp_loss: 51.34655666
# --- response to true image ---
# contribution of the leaky-relu network = 57.999989
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [180/500], avg_loss: 76.76865463, avg_gp_loss: 28.57219715, avg_pp_loss: 48.19645748
# --- response to true image ---
# contribution of the leaky-relu network = 44.613407
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [200/500], avg_loss: 77.51106071, avg_gp_loss: 28.68850050, avg_pp_loss: 48.82255955
# --- response to true image ---
# contribution of the leaky-relu network = 44.347820
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [220/500], avg_loss: 77.38606815, avg_gp_loss: 27.79357824, avg_pp_loss: 49.59248981
# --- response to true image ---
# contribution of the leaky-relu network = 62.169739
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [240/500], avg_loss: 79.77079945, avg_gp_loss: 29.98805532, avg_pp_loss: 49.78274403
# --- response to true image ---
# contribution of the leaky-relu network = 68.557045
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [260/500], avg_loss: 78.92852020, avg_gp_loss: 28.07851639, avg_pp_loss: 50.85000343
# --- response to true image ---
# contribution of the leaky-relu network = 58.065765
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [280/500], avg_loss: 74.58321743, avg_gp_loss: 26.58178992, avg_pp_loss: 48.00142765
# --- response to true image ---
# contribution of the leaky-relu network = 45.204178
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [300/500], avg_loss: 79.69519634, avg_gp_loss: 29.51329603, avg_pp_loss: 50.18190041
# --- response to true image ---
# contribution of the leaky-relu network = 74.365005
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [320/500], avg_loss: 79.18761883, avg_gp_loss: 28.46470151, avg_pp_loss: 50.72291756
# --- response to true image ---
# contribution of the leaky-relu network = 41.444389
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [340/500], avg_loss: 78.44399624, avg_gp_loss: 27.53018308, avg_pp_loss: 50.91381340
# --- response to true image ---
# contribution of the leaky-relu network = 49.861683
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [360/500], avg_loss: 76.60970001, avg_gp_loss: 27.55015478, avg_pp_loss: 49.05954533
# --- response to true image ---
# contribution of the leaky-relu network = 43.299984
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [380/500], avg_loss: 84.61650391, avg_gp_loss: 31.00607224, avg_pp_loss: 53.61043167
# --- response to true image ---
# contribution of the leaky-relu network = 54.642952
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [400/500], avg_loss: 81.73519592, avg_gp_loss: 30.14159832, avg_pp_loss: 51.59359703
# --- response to true image ---
# contribution of the leaky-relu network = 55.892849
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [420/500], avg_loss: 90.08096466, avg_gp_loss: 32.36074924, avg_pp_loss: 57.72021542
# --- response to true image ---
# contribution of the leaky-relu network = 57.663235
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [440/500], avg_loss: 79.85314407, avg_gp_loss: 28.52973633, avg_pp_loss: 51.32340813
# --- response to true image ---
# contribution of the leaky-relu network = 50.444794
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [460/500], avg_loss: 81.18183842, avg_gp_loss: 28.99798689, avg_pp_loss: 52.18385162
# --- response to true image ---
# contribution of the leaky-relu network = 54.580414
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [480/500], avg_loss: 81.68213634, avg_gp_loss: 29.80470619, avg_pp_loss: 51.87742977
# --- response to true image ---
# contribution of the leaky-relu network = 37.181454
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [500/500], avg_loss: 81.48440552, avg_gp_loss: 29.25776186, avg_pp_loss: 52.22664375
# --- response to true image ---
# contribution of the leaky-relu network = 60.701298
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [20/500], avg_loss: 80.68973007, avg_gp_loss: 28.77647285, avg_pp_loss: 51.91325645
# --- response to true image ---
# contribution of the leaky-relu network = 44.264957
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [40/500], avg_loss: 76.41505165, avg_gp_loss: 27.84215450, avg_pp_loss: 48.57289696
# --- response to true image ---
# contribution of the leaky-relu network = 43.941856
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [60/500], avg_loss: 77.74827099, avg_gp_loss: 28.60887232, avg_pp_loss: 49.13939857
# --- response to true image ---
# contribution of the leaky-relu network = 50.037106
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [80/500], avg_loss: 83.07734489, avg_gp_loss: 29.77693939, avg_pp_loss: 53.30040569
# --- response to true image ---
# contribution of the leaky-relu network = 55.144161
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [100/500], avg_loss: 80.41619244, avg_gp_loss: 29.43238368, avg_pp_loss: 50.98380795
# --- response to true image ---
# contribution of the leaky-relu network = 29.475830
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [120/500], avg_loss: 76.70764637, avg_gp_loss: 27.44680886, avg_pp_loss: 49.26083698
# --- response to true image ---
# contribution of the leaky-relu network = 48.461624
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [140/500], avg_loss: 79.68659344, avg_gp_loss: 29.08530645, avg_pp_loss: 50.60128632
# --- response to true image ---
# contribution of the leaky-relu network = 40.095032
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [160/500], avg_loss: 85.12047691, avg_gp_loss: 30.45890865, avg_pp_loss: 54.66156731
# --- response to true image ---
# contribution of the leaky-relu network = 63.616978
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [180/500], avg_loss: 76.18639317, avg_gp_loss: 27.24196920, avg_pp_loss: 48.94442387
# --- response to true image ---
# contribution of the leaky-relu network = 43.888966
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [200/500], avg_loss: 80.48614693, avg_gp_loss: 29.29316940, avg_pp_loss: 51.19297810
# --- response to true image ---
# contribution of the leaky-relu network = 67.147377
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [220/500], avg_loss: 80.86629353, avg_gp_loss: 28.81885109, avg_pp_loss: 52.04744225
# --- response to true image ---
# contribution of the leaky-relu network = 66.512169
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [240/500], avg_loss: 80.63206043, avg_gp_loss: 28.90106134, avg_pp_loss: 51.73099976
# --- response to true image ---
# contribution of the leaky-relu network = 58.923767
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [260/500], avg_loss: 81.54836769, avg_gp_loss: 29.48745193, avg_pp_loss: 52.06091595
# --- response to true image ---
# contribution of the leaky-relu network = 44.402191
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [280/500], avg_loss: 85.97153473, avg_gp_loss: 31.39916449, avg_pp_loss: 54.57237072
# --- response to true image ---
# contribution of the leaky-relu network = 80.891350
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [300/500], avg_loss: 78.40650787, avg_gp_loss: 28.64703512, avg_pp_loss: 49.75947323
# --- response to true image ---
# contribution of the leaky-relu network = 38.659893
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [320/500], avg_loss: 78.87292614, avg_gp_loss: 29.57640324, avg_pp_loss: 49.29652328
# --- response to true image ---
# contribution of the leaky-relu network = 35.256805
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [340/500], avg_loss: 79.94708481, avg_gp_loss: 28.78699293, avg_pp_loss: 51.16009159
# --- response to true image ---
# contribution of the leaky-relu network = 51.336735
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [360/500], avg_loss: 79.78156357, avg_gp_loss: 28.64047890, avg_pp_loss: 51.14108467
# --- response to true image ---
# contribution of the leaky-relu network = 60.541637
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [380/500], avg_loss: 85.36310043, avg_gp_loss: 30.85276041, avg_pp_loss: 54.51033936
# --- response to true image ---
# contribution of the leaky-relu network = 76.418060
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [400/500], avg_loss: 76.53385353, avg_gp_loss: 28.18885050, avg_pp_loss: 48.34500294
# --- response to true image ---
# contribution of the leaky-relu network = 48.793861
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [420/500], avg_loss: 75.31541119, avg_gp_loss: 28.24657097, avg_pp_loss: 47.06884022
# --- response to true image ---
# contribution of the leaky-relu network = 60.781197
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [440/500], avg_loss: 82.16270485, avg_gp_loss: 29.17163601, avg_pp_loss: 52.99106808
# --- response to true image ---
# contribution of the leaky-relu network = 74.664124
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [460/500], avg_loss: 77.25969696, avg_gp_loss: 28.41169701, avg_pp_loss: 48.84799938
# --- response to true image ---
# contribution of the leaky-relu network = 38.941631
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [480/500], avg_loss: 80.98524952, avg_gp_loss: 29.10645208, avg_pp_loss: 51.87879734
# --- response to true image ---
# contribution of the leaky-relu network = 50.266895
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [500/500], avg_loss: 81.02906837, avg_gp_loss: 29.39893217, avg_pp_loss: 51.63013592
# --- response to true image ---
# contribution of the leaky-relu network = 57.198456
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [20/500], avg_loss: 76.47392063, avg_gp_loss: 27.33348684, avg_pp_loss: 49.14043350
# --- response to true image ---
# contribution of the leaky-relu network = 34.823727
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [40/500], avg_loss: 83.42015419, avg_gp_loss: 30.44673710, avg_pp_loss: 52.97341709
# --- response to true image ---
# contribution of the leaky-relu network = 70.276070
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [60/500], avg_loss: 79.94695644, avg_gp_loss: 28.80780821, avg_pp_loss: 51.13914833
# --- response to true image ---
# contribution of the leaky-relu network = 59.699253
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [80/500], avg_loss: 82.54944668, avg_gp_loss: 29.43353162, avg_pp_loss: 53.11591434
# --- response to true image ---
# contribution of the leaky-relu network = 62.989971
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [100/500], avg_loss: 85.23781052, avg_gp_loss: 30.69432831, avg_pp_loss: 54.54348297
# --- response to true image ---
# contribution of the leaky-relu network = 60.646454
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [120/500], avg_loss: 81.62451553, avg_gp_loss: 29.22498770, avg_pp_loss: 52.39952850
# --- response to true image ---
# contribution of the leaky-relu network = 53.717609
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [140/500], avg_loss: 81.45907230, avg_gp_loss: 29.53678198, avg_pp_loss: 51.92229023
# --- response to true image ---
# contribution of the leaky-relu network = 57.812424
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [160/500], avg_loss: 79.71108742, avg_gp_loss: 28.98987646, avg_pp_loss: 50.72120953
# --- response to true image ---
# contribution of the leaky-relu network = 43.290825
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [180/500], avg_loss: 80.76594810, avg_gp_loss: 29.29996119, avg_pp_loss: 51.46598682
# --- response to true image ---
# contribution of the leaky-relu network = 55.562389
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [200/500], avg_loss: 82.72539845, avg_gp_loss: 30.58073549, avg_pp_loss: 52.14466286
# --- response to true image ---
# contribution of the leaky-relu network = 57.531185
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [220/500], avg_loss: 81.84376469, avg_gp_loss: 29.15260496, avg_pp_loss: 52.69115982
# --- response to true image ---
# contribution of the leaky-relu network = 66.623642
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [240/500], avg_loss: 77.59041634, avg_gp_loss: 27.71482692, avg_pp_loss: 49.87558899
# --- response to true image ---
# contribution of the leaky-relu network = 59.845901
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [260/500], avg_loss: 71.13171883, avg_gp_loss: 26.27199750, avg_pp_loss: 44.85972233
# --- response to true image ---
# contribution of the leaky-relu network = 41.138134
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [280/500], avg_loss: 77.63284073, avg_gp_loss: 28.32189121, avg_pp_loss: 49.31094894
# --- response to true image ---
# contribution of the leaky-relu network = 50.676842
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [300/500], avg_loss: 76.98995743, avg_gp_loss: 28.41692619, avg_pp_loss: 48.57303181
# --- response to true image ---
# contribution of the leaky-relu network = 37.317982
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [320/500], avg_loss: 80.38648415, avg_gp_loss: 29.46472330, avg_pp_loss: 50.92176132
# --- response to true image ---
# contribution of the leaky-relu network = 58.748043
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [340/500], avg_loss: 81.36871510, avg_gp_loss: 29.58280482, avg_pp_loss: 51.78591003
# --- response to true image ---
# contribution of the leaky-relu network = 49.855503
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [360/500], avg_loss: 80.43723373, avg_gp_loss: 29.38879442, avg_pp_loss: 51.04843941
# --- response to true image ---
# contribution of the leaky-relu network = 65.487381
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [380/500], avg_loss: 76.21299648, avg_gp_loss: 27.70874500, avg_pp_loss: 48.50425167
# --- response to true image ---
# contribution of the leaky-relu network = 54.252083
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [400/500], avg_loss: 83.92045860, avg_gp_loss: 30.68207016, avg_pp_loss: 53.23838825
# --- response to true image ---
# contribution of the leaky-relu network = 42.255768
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [420/500], avg_loss: 76.61057644, avg_gp_loss: 27.55677290, avg_pp_loss: 49.05380402
# --- response to true image ---
# contribution of the leaky-relu network = 45.766228
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [440/500], avg_loss: 77.74774551, avg_gp_loss: 28.21045961, avg_pp_loss: 49.53728600
# --- response to true image ---
# contribution of the leaky-relu network = 57.541531
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [460/500], avg_loss: 83.34084797, avg_gp_loss: 29.45468335, avg_pp_loss: 53.88616486
# --- response to true image ---
# contribution of the leaky-relu network = 51.763432
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [480/500], avg_loss: 82.85267448, avg_gp_loss: 30.26592379, avg_pp_loss: 52.58675117
# --- response to true image ---
# contribution of the leaky-relu network = 67.283699
# ==================
# ----single convex MYE----
# epoch: [6/10], mini-batch: [500/500], avg_loss: 80.00177460, avg_gp_loss: 29.51623411, avg_pp_loss: 50.48554058
# --- response to true image ---
# contribution of the leaky-relu network = 74.854576
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [20/500], avg_loss: 81.07770195, avg_gp_loss: 28.29870205, avg_pp_loss: 52.77899990
# --- response to true image ---
# contribution of the leaky-relu network = 41.216347
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [40/500], avg_loss: 80.10903111, avg_gp_loss: 29.47311678, avg_pp_loss: 50.63591480
# --- response to true image ---
# contribution of the leaky-relu network = 61.396294
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [60/500], avg_loss: 81.00282497, avg_gp_loss: 28.88857918, avg_pp_loss: 52.11424637
# --- response to true image ---
# contribution of the leaky-relu network = 69.058807
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [80/500], avg_loss: 79.09286766, avg_gp_loss: 29.11618876, avg_pp_loss: 49.97667770
# --- response to true image ---
# contribution of the leaky-relu network = 38.535484
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [100/500], avg_loss: 80.73558254, avg_gp_loss: 28.64894419, avg_pp_loss: 52.08663845
# --- response to true image ---
# contribution of the leaky-relu network = 59.495926
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [120/500], avg_loss: 80.93712959, avg_gp_loss: 29.31828527, avg_pp_loss: 51.61884499
# --- response to true image ---
# contribution of the leaky-relu network = 36.338390
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [140/500], avg_loss: 79.08164043, avg_gp_loss: 28.23587666, avg_pp_loss: 50.84576416
# --- response to true image ---
# contribution of the leaky-relu network = 46.968697
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [160/500], avg_loss: 81.39702911, avg_gp_loss: 29.65212069, avg_pp_loss: 51.74490814
# --- response to true image ---
# contribution of the leaky-relu network = 47.422482
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [180/500], avg_loss: 85.98113403, avg_gp_loss: 31.55429878, avg_pp_loss: 54.42683506
# --- response to true image ---
# contribution of the leaky-relu network = 53.903999
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [200/500], avg_loss: 79.28419476, avg_gp_loss: 29.21622467, avg_pp_loss: 50.06797028
# --- response to true image ---
# contribution of the leaky-relu network = 41.784248
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [220/500], avg_loss: 79.62671127, avg_gp_loss: 29.28435574, avg_pp_loss: 50.34235535
# --- response to true image ---
# contribution of the leaky-relu network = 66.035019
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [240/500], avg_loss: 81.82958298, avg_gp_loss: 29.25338864, avg_pp_loss: 52.57619400
# --- response to true image ---
# contribution of the leaky-relu network = 63.445145
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [260/500], avg_loss: 75.36687584, avg_gp_loss: 28.29950418, avg_pp_loss: 47.06737194
# --- response to true image ---
# contribution of the leaky-relu network = 48.608608
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [280/500], avg_loss: 76.72611465, avg_gp_loss: 27.79723921, avg_pp_loss: 48.92887554
# --- response to true image ---
# contribution of the leaky-relu network = 37.718517
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [300/500], avg_loss: 85.64951782, avg_gp_loss: 30.24579620, avg_pp_loss: 55.40372105
# --- response to true image ---
# contribution of the leaky-relu network = 38.270420
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [320/500], avg_loss: 79.73706551, avg_gp_loss: 28.85387845, avg_pp_loss: 50.88318634
# --- response to true image ---
# contribution of the leaky-relu network = 48.807423
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [340/500], avg_loss: 78.86716022, avg_gp_loss: 28.41925554, avg_pp_loss: 50.44790440
# --- response to true image ---
# contribution of the leaky-relu network = 51.614044
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [360/500], avg_loss: 74.15624313, avg_gp_loss: 27.26347089, avg_pp_loss: 46.89277210
# --- response to true image ---
# contribution of the leaky-relu network = 45.254318
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [380/500], avg_loss: 78.86040192, avg_gp_loss: 28.56749306, avg_pp_loss: 50.29290848
# --- response to true image ---
# contribution of the leaky-relu network = 46.949612
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [400/500], avg_loss: 78.89024525, avg_gp_loss: 28.94573526, avg_pp_loss: 49.94451027
# --- response to true image ---
# contribution of the leaky-relu network = 44.341965
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [420/500], avg_loss: 76.07592354, avg_gp_loss: 27.38973579, avg_pp_loss: 48.68618793
# --- response to true image ---
# contribution of the leaky-relu network = 71.188972
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [440/500], avg_loss: 80.53865547, avg_gp_loss: 29.65731144, avg_pp_loss: 50.88134327
# --- response to true image ---
# contribution of the leaky-relu network = 31.143780
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [460/500], avg_loss: 81.29418335, avg_gp_loss: 29.83891973, avg_pp_loss: 51.45526409
# --- response to true image ---
# contribution of the leaky-relu network = 40.863064
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [480/500], avg_loss: 82.23142395, avg_gp_loss: 29.94432802, avg_pp_loss: 52.28709602
# --- response to true image ---
# contribution of the leaky-relu network = 79.860641
# ==================
# ----single convex MYE----
# epoch: [7/10], mini-batch: [500/500], avg_loss: 81.83210526, avg_gp_loss: 29.80733652, avg_pp_loss: 52.02476864
# --- response to true image ---
# contribution of the leaky-relu network = 36.618668
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [20/500], avg_loss: 76.78410206, avg_gp_loss: 28.09159546, avg_pp_loss: 48.69250679
# --- response to true image ---
# contribution of the leaky-relu network = 45.320831
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [40/500], avg_loss: 79.73913727, avg_gp_loss: 29.13301668, avg_pp_loss: 50.60612049
# --- response to true image ---
# contribution of the leaky-relu network = 62.705376
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [60/500], avg_loss: 84.15772972, avg_gp_loss: 30.71283159, avg_pp_loss: 53.44489746
# --- response to true image ---
# contribution of the leaky-relu network = 56.181870
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [80/500], avg_loss: 81.30118809, avg_gp_loss: 29.38926282, avg_pp_loss: 51.91192493
# --- response to true image ---
# contribution of the leaky-relu network = 66.041939
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [100/500], avg_loss: 79.77729893, avg_gp_loss: 28.63174963, avg_pp_loss: 51.14554901
# --- response to true image ---
# contribution of the leaky-relu network = 70.706161
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [120/500], avg_loss: 87.80239830, avg_gp_loss: 31.53542757, avg_pp_loss: 56.26696968
# --- response to true image ---
# contribution of the leaky-relu network = 72.067215
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [140/500], avg_loss: 78.93942451, avg_gp_loss: 27.79230375, avg_pp_loss: 51.14712048
# --- response to true image ---
# contribution of the leaky-relu network = 61.556461
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [160/500], avg_loss: 80.28178310, avg_gp_loss: 29.65343380, avg_pp_loss: 50.62834854
# --- response to true image ---
# contribution of the leaky-relu network = 70.214149
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [180/500], avg_loss: 80.71639004, avg_gp_loss: 29.56992135, avg_pp_loss: 51.14646873
# --- response to true image ---
# contribution of the leaky-relu network = 53.671047
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [200/500], avg_loss: 82.88873730, avg_gp_loss: 29.87331133, avg_pp_loss: 53.01542625
# --- response to true image ---
# contribution of the leaky-relu network = 44.752731
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [220/500], avg_loss: 77.27786751, avg_gp_loss: 27.93387241, avg_pp_loss: 49.34399529
# --- response to true image ---
# contribution of the leaky-relu network = 53.446678
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [240/500], avg_loss: 81.39273777, avg_gp_loss: 30.46814890, avg_pp_loss: 50.92458916
# --- response to true image ---
# contribution of the leaky-relu network = 70.805023
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [260/500], avg_loss: 83.01694241, avg_gp_loss: 30.34059258, avg_pp_loss: 52.67634869
# --- response to true image ---
# contribution of the leaky-relu network = 57.820107
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [280/500], avg_loss: 80.24567928, avg_gp_loss: 29.01271753, avg_pp_loss: 51.23296165
# --- response to true image ---
# contribution of the leaky-relu network = 79.407806
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [300/500], avg_loss: 75.88045387, avg_gp_loss: 27.80246286, avg_pp_loss: 48.07799034
# --- response to true image ---
# contribution of the leaky-relu network = 46.985691
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [320/500], avg_loss: 79.01224365, avg_gp_loss: 28.09730139, avg_pp_loss: 50.91494274
# --- response to true image ---
# contribution of the leaky-relu network = 64.361710
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [340/500], avg_loss: 76.86865578, avg_gp_loss: 28.48499765, avg_pp_loss: 48.38365784
# --- response to true image ---
# contribution of the leaky-relu network = 72.167000
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [360/500], avg_loss: 83.47120953, avg_gp_loss: 28.47077136, avg_pp_loss: 55.00043793
# --- response to true image ---
# contribution of the leaky-relu network = 58.104412
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [380/500], avg_loss: 77.68077526, avg_gp_loss: 27.81468015, avg_pp_loss: 49.86609554
# --- response to true image ---
# contribution of the leaky-relu network = 67.307190
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [400/500], avg_loss: 79.05396576, avg_gp_loss: 27.94091959, avg_pp_loss: 51.11304588
# --- response to true image ---
# contribution of the leaky-relu network = 35.183025
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [420/500], avg_loss: 80.68670731, avg_gp_loss: 29.26335382, avg_pp_loss: 51.42335281
# --- response to true image ---
# contribution of the leaky-relu network = 48.864426
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [440/500], avg_loss: 79.34686527, avg_gp_loss: 28.28538227, avg_pp_loss: 51.06148396
# --- response to true image ---
# contribution of the leaky-relu network = 66.681221
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [460/500], avg_loss: 80.43540707, avg_gp_loss: 30.17904577, avg_pp_loss: 50.25636139
# --- response to true image ---
# contribution of the leaky-relu network = 50.880032
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [480/500], avg_loss: 76.21627789, avg_gp_loss: 28.44657097, avg_pp_loss: 47.76970596
# --- response to true image ---
# contribution of the leaky-relu network = 37.322571
# ==================
# ----single convex MYE----
# epoch: [8/10], mini-batch: [500/500], avg_loss: 77.17307053, avg_gp_loss: 28.61989689, avg_pp_loss: 48.55317345
# --- response to true image ---
# contribution of the leaky-relu network = 38.264099
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [20/500], avg_loss: 75.84028454, avg_gp_loss: 27.43106122, avg_pp_loss: 48.40922260
# --- response to true image ---
# contribution of the leaky-relu network = 31.445833
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [40/500], avg_loss: 79.15442696, avg_gp_loss: 28.35941849, avg_pp_loss: 50.79500923
# --- response to true image ---
# contribution of the leaky-relu network = 52.567398
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [60/500], avg_loss: 75.82452927, avg_gp_loss: 28.39043241, avg_pp_loss: 47.43409672
# --- response to true image ---
# contribution of the leaky-relu network = 50.475292
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [80/500], avg_loss: 83.74268265, avg_gp_loss: 29.96641374, avg_pp_loss: 53.77626915
# --- response to true image ---
# contribution of the leaky-relu network = 50.030018
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [100/500], avg_loss: 72.59043655, avg_gp_loss: 25.95627861, avg_pp_loss: 46.63415756
# --- response to true image ---
# contribution of the leaky-relu network = 43.062012
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [120/500], avg_loss: 76.01372356, avg_gp_loss: 28.63093853, avg_pp_loss: 47.38278580
# --- response to true image ---
# contribution of the leaky-relu network = 56.482925
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [140/500], avg_loss: 79.15846176, avg_gp_loss: 29.48447905, avg_pp_loss: 49.67398243
# --- response to true image ---
# contribution of the leaky-relu network = 69.802208
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [160/500], avg_loss: 81.46473637, avg_gp_loss: 29.58571634, avg_pp_loss: 51.87902050
# --- response to true image ---
# contribution of the leaky-relu network = 60.658367
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [180/500], avg_loss: 86.46756687, avg_gp_loss: 30.62707186, avg_pp_loss: 55.84049473
# --- response to true image ---
# contribution of the leaky-relu network = 68.665543
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [200/500], avg_loss: 80.55504265, avg_gp_loss: 28.96297398, avg_pp_loss: 51.59206905
# --- response to true image ---
# contribution of the leaky-relu network = 47.785046
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [220/500], avg_loss: 80.71494617, avg_gp_loss: 29.23403492, avg_pp_loss: 51.48091221
# --- response to true image ---
# contribution of the leaky-relu network = 52.921528
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [240/500], avg_loss: 83.90490913, avg_gp_loss: 30.38542280, avg_pp_loss: 53.51948719
# --- response to true image ---
# contribution of the leaky-relu network = 62.167843
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [260/500], avg_loss: 79.27500668, avg_gp_loss: 28.54770422, avg_pp_loss: 50.72730350
# --- response to true image ---
# contribution of the leaky-relu network = 64.354225
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [280/500], avg_loss: 82.09213486, avg_gp_loss: 30.01314783, avg_pp_loss: 52.07898731
# --- response to true image ---
# contribution of the leaky-relu network = 83.868835
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [300/500], avg_loss: 80.68286819, avg_gp_loss: 30.05194073, avg_pp_loss: 50.63092804
# --- response to true image ---
# contribution of the leaky-relu network = 62.299347
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [320/500], avg_loss: 85.33614674, avg_gp_loss: 30.68881865, avg_pp_loss: 54.64732933
# --- response to true image ---
# contribution of the leaky-relu network = 61.789577
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [340/500], avg_loss: 80.08860130, avg_gp_loss: 29.13035126, avg_pp_loss: 50.95824966
# --- response to true image ---
# contribution of the leaky-relu network = 57.462547
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [360/500], avg_loss: 80.34261456, avg_gp_loss: 29.08860946, avg_pp_loss: 51.25400562
# --- response to true image ---
# contribution of the leaky-relu network = 32.146824
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [380/500], avg_loss: 80.05728531, avg_gp_loss: 28.76848588, avg_pp_loss: 51.28879967
# --- response to true image ---
# contribution of the leaky-relu network = 39.713642
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [400/500], avg_loss: 77.60992985, avg_gp_loss: 28.00088062, avg_pp_loss: 49.60904846
# --- response to true image ---
# contribution of the leaky-relu network = 43.838219
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [420/500], avg_loss: 82.09819298, avg_gp_loss: 29.55728111, avg_pp_loss: 52.54091244
# --- response to true image ---
# contribution of the leaky-relu network = 48.973400
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [440/500], avg_loss: 80.27022018, avg_gp_loss: 29.38684492, avg_pp_loss: 50.88337574
# --- response to true image ---
# contribution of the leaky-relu network = 62.053577
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [460/500], avg_loss: 78.49303455, avg_gp_loss: 28.24020433, avg_pp_loss: 50.25283051
# --- response to true image ---
# contribution of the leaky-relu network = 30.006487
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [480/500], avg_loss: 78.66070976, avg_gp_loss: 28.54271479, avg_pp_loss: 50.11799545
# --- response to true image ---
# contribution of the leaky-relu network = 56.373421
# ==================
# ----single convex MYE----
# epoch: [9/10], mini-batch: [500/500], avg_loss: 77.75438576, avg_gp_loss: 28.36882820, avg_pp_loss: 49.38555756
# --- response to true image ---
# contribution of the leaky-relu network = 58.469090
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [20/500], avg_loss: 81.74518833, avg_gp_loss: 30.18345022, avg_pp_loss: 51.56173840
# --- response to true image ---
# contribution of the leaky-relu network = 60.068558
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [40/500], avg_loss: 74.70655766, avg_gp_loss: 26.86180868, avg_pp_loss: 47.84474907
# --- response to true image ---
# contribution of the leaky-relu network = 56.803505
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [60/500], avg_loss: 80.06718025, avg_gp_loss: 28.89537458, avg_pp_loss: 51.17180595
# --- response to true image ---
# contribution of the leaky-relu network = 45.541294
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [80/500], avg_loss: 74.67262993, avg_gp_loss: 27.64250784, avg_pp_loss: 47.03012142
# --- response to true image ---
# contribution of the leaky-relu network = 75.291443
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [100/500], avg_loss: 81.19738789, avg_gp_loss: 29.95037260, avg_pp_loss: 51.24701500
# --- response to true image ---
# contribution of the leaky-relu network = 78.709641
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [120/500], avg_loss: 81.13710766, avg_gp_loss: 29.16663599, avg_pp_loss: 51.97047195
# --- response to true image ---
# contribution of the leaky-relu network = 49.194256
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [140/500], avg_loss: 76.20812321, avg_gp_loss: 27.65680342, avg_pp_loss: 48.55131931
# --- response to true image ---
# contribution of the leaky-relu network = 39.224720
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [160/500], avg_loss: 77.90551414, avg_gp_loss: 29.32912712, avg_pp_loss: 48.57638683
# --- response to true image ---
# contribution of the leaky-relu network = 54.382568
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [180/500], avg_loss: 78.38075600, avg_gp_loss: 28.43831077, avg_pp_loss: 49.94244518
# --- response to true image ---
# contribution of the leaky-relu network = 48.760883
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [200/500], avg_loss: 80.74991150, avg_gp_loss: 29.26842756, avg_pp_loss: 51.48148460
# --- response to true image ---
# contribution of the leaky-relu network = 46.383801
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [220/500], avg_loss: 83.24532242, avg_gp_loss: 30.08720179, avg_pp_loss: 53.15812073
# --- response to true image ---
# contribution of the leaky-relu network = 62.100273
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [240/500], avg_loss: 77.91849537, avg_gp_loss: 28.65334721, avg_pp_loss: 49.26514854
# --- response to true image ---
# contribution of the leaky-relu network = 46.251465
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [260/500], avg_loss: 84.72089825, avg_gp_loss: 31.23121891, avg_pp_loss: 53.48967915
# --- response to true image ---
# contribution of the leaky-relu network = 50.803322
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [280/500], avg_loss: 77.76568108, avg_gp_loss: 27.92476921, avg_pp_loss: 49.84091263
# --- response to true image ---
# contribution of the leaky-relu network = 35.522888
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [300/500], avg_loss: 75.92120628, avg_gp_loss: 27.44544001, avg_pp_loss: 48.47576675
# --- response to true image ---
# contribution of the leaky-relu network = 86.912048
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [320/500], avg_loss: 80.09801559, avg_gp_loss: 28.73744488, avg_pp_loss: 51.36057014
# --- response to true image ---
# contribution of the leaky-relu network = 71.746040
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [340/500], avg_loss: 80.63918800, avg_gp_loss: 29.20371771, avg_pp_loss: 51.43546963
# --- response to true image ---
# contribution of the leaky-relu network = 62.207844
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [360/500], avg_loss: 83.36049919, avg_gp_loss: 30.72361994, avg_pp_loss: 52.63687935
# --- response to true image ---
# contribution of the leaky-relu network = 81.143936
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [380/500], avg_loss: 86.28580265, avg_gp_loss: 30.36725693, avg_pp_loss: 55.91854668
# --- response to true image ---
# contribution of the leaky-relu network = 82.961586
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [400/500], avg_loss: 80.28346691, avg_gp_loss: 28.90014200, avg_pp_loss: 51.38332500
# --- response to true image ---
# contribution of the leaky-relu network = 57.726486
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [420/500], avg_loss: 78.75102730, avg_gp_loss: 28.66764221, avg_pp_loss: 50.08338528
# --- response to true image ---
# contribution of the leaky-relu network = 65.532661
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [440/500], avg_loss: 87.58583145, avg_gp_loss: 31.29862385, avg_pp_loss: 56.28720798
# --- response to true image ---
# contribution of the leaky-relu network = 49.777737
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [460/500], avg_loss: 78.83262844, avg_gp_loss: 28.29938469, avg_pp_loss: 50.53324337
# --- response to true image ---
# contribution of the leaky-relu network = 53.680733
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [480/500], avg_loss: 80.10818481, avg_gp_loss: 28.09156709, avg_pp_loss: 52.01661835
# --- response to true image ---
# contribution of the leaky-relu network = 53.075489
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [500/500], avg_loss: 77.72157936, avg_gp_loss: 28.47124033, avg_pp_loss: 49.25033913
# --- response to true image ---
# contribution of the leaky-relu network = 63.855522

# %%
#save the models 
pretrained_network_path = '../models/l1reg_pretrained_nets/'
os.makedirs(pretrained_network_path, exist_ok=True)
# torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
# torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
# torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_" + 'epoch_%02d'%epoch + ".pt") 

# torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_paired.pt")
# torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_paired.pt")
# torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_paired.pt")

# %%
import matplotlib.pyplot as plt
pretrained_network_path = '../models/l1reg_pretrained_nets/'

avg_loss_mye_paired_arr = np.array(avg_loss_mye_paired, dtype=np.float32)
# avg_loss_mye_unpaired_arr = np.load(pretrained_network_path + "avg_loss_mye_unpaired_arr.npy")
np.save(pretrained_network_path + "avg_loss_mye_paired_arr.npy", avg_loss_mye_paired_arr)
train_steps = np.arange(1, 1+avg_loss_mye_paired_arr.size)

# plt.plot(train_steps, avg_loss_mye_paired_arr, 'r', train_steps, avg_loss_acr_unpaired_arr, 'b', linewidth=2.0)
# plt.legend(['paired', 'unpaired'], fontsize=24.0)


plt.plot(train_steps, avg_loss_mye_paired_arr, 'r', linewidth=2.0)

# plt.plot(train_steps, avg_loss_mye_unpaired_arr, 'b', linewidth=2.0)

plt.gcf().set_size_inches(11.0,8.0)
plt.xlabel('training steps', fontsize=28.0)
plt.ylabel('training loss', fontsize=28.0)
plt.tick_params(axis='both', which='major', labelsize=24.0)
plt.grid()

plt.savefig(pretrained_network_path + 'unpaired_train.png', bbox_inches='tight', transparent = False, pad_inches=0.1)
#plt.savefig(pretrained_network_path + 'paired_vs_unpaired_train_combined.png', bbox_inches='tight', transparent = False, pad_inches=0.1)
#plt.savefig(pretrained_network_path + 'paired_train.png', bbox_inches='tight', transparent = False, pad_inches=0.1)

plt.show()

# %%
#check convexity of the net
n_trials = 50
convexity = 0
for trial in np.arange(n_trials):
    x1 = torch.rand(dummy_input.size()).to(device)
    x2 = torch.rand(dummy_input.size()).to(device)
    alpha = torch.rand(1).to(device)

    cvx_combo_of_input = mye(alpha * x1 + (1-alpha)*x2)
    cvx_combo_of_output = alpha * mye(x1) + (1-alpha)*mye(x2)

    convexity += (cvx_combo_of_input.mean() <= cvx_combo_of_output.mean())
if(convexity == n_trials):
    print('the net is %s'%'convex') 
else:
    print('the net is %s'%'non-convex')
# Out:
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# the net is convex

# %%
# compare output to exact solution
import matplotlib.pyplot as plt
steps = 100

sample = next(iter(train_dataloader))["ground_truth"]
sample_ = sample.detach().numpy()[0][0]
plt.imshow(sample_, cmap=plt.get_cmap('gray'))
plt.show()

x_ij = torch.linspace(start=0., end=1.,steps=steps)
x = torch.zeros((steps,) + sample[0].shape)
for k in range(steps):
    x[k,0] = sample
    x[k,0,2,3] = x_ij[k]


# x = sample[0]
# print(x.shape)
# x.expand(steps, 28, 28) # specifies new size
# print(x.shape)
# x.repeat(steps,1,1,1) # specifies number of copies

# x[:,0,2,3] = x_ij

new_sample_ = x.detach().numpy()[50][0]
plt.imshow(new_sample_, cmap=plt.get_cmap('gray'))
plt.show()
g_lambda = mye(x)
    
def mye_l1(lambd,x):
    z = np.zeros((x.shape[0], x.shape[2], x.shape[3]))
    for k in range(x.shape[0]):
        for i in range(x.shape[2]):
            for j in range(x.shape[3]):
#                 if i==2 and j==3:
#                     print(x[k,0,i,j])
                if x[k,0,i,j].abs() < lambd:
                    z[k,i,j] = 1/(2*lambd) * x[k,0,i,j]**2
                else:
                    z[k,i,j] = np.abs(x[k,0,i,j]) - lambd/2

    mye = np.sum(z,axis=(1,2))

    return mye
        
    
gt = mye_l1(alpha*lamb,x)
print(gt.shape)

plt.plot(x_ij.detach().numpy(),g_lambda.detach().numpy())
plt.plot(x_ij.detach().numpy(),gt)
# Plot ground truth

plt.show()
# Out:
# (100,)
