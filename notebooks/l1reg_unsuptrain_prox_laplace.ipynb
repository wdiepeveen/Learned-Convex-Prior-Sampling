# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torch.utils.data import Dataset
from IPython.display import Image
import numpy as np
import os
import glob
import random
from PIL import Image
from torch.utils.tensorboard import SummaryWriter
import torchvision.utils as vutils
from skimage.measure import compare_ssim, compare_psnr


#writer = SummaryWriter()
import warnings
warnings.filterwarnings(action='once')


device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device = %s'%device)
print('torch version = %s'%(torch.__version__))
print('no. of GPUs = %d'%(torch.cuda.device_count()))

batch_size, n_in_channels, img_size = 1, 1, 10 #for toy problem
val_batch_size = 1
#dataloader
from torch.utils.data import DataLoader

#custom dataset class 
class ImageDataset(Dataset):
    def __init__(self, root, transforms_= None, unaligned = True, mode = 'train'):
        self.transform = transforms.Compose(transforms_)
        self.unaligned = unaligned

        self.files = sorted(glob.glob(os.path.join(root, '%s/groundtruth'% mode) + '/*.*'))


    def __getitem__(self, index):
        if self.unaligned:
            ground_truth = self.transform(Image.fromarray(np.load(self.files[random.randint(0, len(self.files) - 1)])))
        else:
            ground_truth = self.transform(Image.fromarray(np.load(self.files[index % len(self.files)])))
        
        

        return {'ground_truth': ground_truth}

    def __len__(self):
        return len(self.files)
    
transform_train_and_test = [transforms.ToTensor()]
datapath = '../data/l1_toy_data'

#training dataloader: test the performance for unaligned=False, i.e. for aligned/paired data
train_dataloader = DataLoader(ImageDataset(datapath, transforms_=transform_train_and_test, unaligned=False, mode = 'train'),\
                              batch_size = batch_size, shuffle = True) #the samples must be unaligned and shuffled
print('number of minibatches during training = %d'%len(train_dataloader))

#modified sigmoid 
def modified_sigmoid(x, alpha):
    x = 1 + torch.exp(-alpha*x)
    x = torch.div(torch.ones(x.size()).to(device), x)
    return x
# Out:
# device = cpu
# torch version = 1.8.0
# no. of GPUs = 0
# number of minibatches during training = 500

# %%
#build a convex discriminator (for 10 x 10 inputs)
n_filters = 5 #was 48 previously
filt_dim = 5
n_layers = 10

class new_model(nn.Module):
    def __init__(self, n_in_channels=1, n_filters=n_filters, filt_dim=filt_dim, n_layers=n_layers):
        super(new_model, self).__init__()
        
        self.n_layers = n_layers
        self.wz = nn.ModuleList([nn.Conv2d(n_filters, n_filters, kernel_size=filt_dim, stride=1, padding=2, bias=True) for i in range(self.n_layers)])
        
        #these layers can have arbitrary weights
        self.wx = nn.ModuleList([nn.Conv2d(n_in_channels, n_filters, kernel_size=filt_dim, stride=1, padding=2, bias=True) for i in range(self.n_layers+1)])
        
        #one final conv layer with nonnegative weights
        self.final_conv2d = nn.Conv2d(n_filters, 1, kernel_size=filt_dim, stride=1, padding=2, bias=True)
        
        #slope of leaky-relu
        self.negative_slope = 0.2 
        
    def forward(self, x):
        z = F.leaky_relu(self.wx[0](x), negative_slope=self.negative_slope)
        for layer in range(self.n_layers):
            z = F.leaky_relu(self.wz[layer](z), negative_slope=self.negative_slope)
        z = self.final_conv2d(z)
#         z_avg = F.avg_pool2d(z, z.size()[2:]).view(z.size()[0], -1)
        
        return z
    

#realize the model: just one net which outputs a small number for true and large for something noisy 
mye = new_model().to(device) 


#manually initialize weights
#the following are initialized with non-negative weights
def initialize_weights(net, n_layers = n_layers, min_val = -0.001, max_val = 0.001):
    for layer in range(n_layers):
        net.wz[layer].weight.data = min_val + (max_val - min_val) * torch.rand(n_filters,n_filters,filt_dim,filt_dim).to(device)
    
    net.final_conv2d.weight.data = min_val + (max_val - min_val) * torch.rand(1,n_filters,filt_dim,filt_dim).to(device)
    return net

mye = initialize_weights(mye)

#for debugging
dummy_input = torch.rand(batch_size, n_in_channels, img_size, img_size).to(device)
mye_output = mye(dummy_input)
print(mye_output.size())

total_params = sum(p.numel() for p in mye.parameters())
print('total number of parameters in MYE = %d'%total_params)
# Out:
# torch.Size([1, 1, 10, 10])
# total number of parameters in MYE = 7856
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###### FOR DEBUGGING ###### 

#check the contributions of each term in the ACR
noise_sd_for_training_stability = 0.0
for idx, batch in enumerate(train_dataloader):
    ############################################
    images = batch["ground_truth"].to(device) #true images
    batch_size = images.size()[0]

    #true images + slight noise for stability
    real_x = images + noise_sd_for_training_stability*torch.randn(batch_size,n_in_channels,img_size,img_size).to(device) 
    
    #for true image
    mye_output = mye(real_x)
    print('--- response to true image ---')
    print('contribution of the leaky-relu network = %.6f'%torch.sum(mye_output))
    
    break
# Out:
# --- response to true image ---
# contribution of the leaky-relu network = 5.008121
# /Users/wdiepeveen/PycharmProjects/Learned-Convex-Prior-Sampling/lib/python3.8/site-packages/torchvision/transforms/functional.py:132: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:143.)
#   img = torch.from_numpy(np.array(pic, np.float32, copy=False))

# %%
import torch.autograd as autograd

def compute_l1_mye_penalty(net, samples, lamb): # for a general regularizer, we can use a simular function
    # Compute l2 gradient norm loss
    prox = net(samples)
    gradient_penalty = 1./2 * ((samples - prox).view(samples.size(0),-1).norm(2, dim=1) ** 2).mean() 
    # Compute prior loss, i.e., l1 loss
#     samples = samples.view(samples.size(0),-1)
    prior_penalty = (prox.view(samples.size(0),-1)).norm(1, dim=1).mean()
    
    loss = gradient_penalty + lamb * prior_penalty

    return loss, gradient_penalty, lamb * prior_penalty

# %%
###########
import itertools
betas = (0.5, 0.99) 

#trained without FoE
#optimizer_acr = torch.optim.Adam(itertools.chain(acr.parameters(),l2_net.parameters()), lr=2*1e-5, betas=betas, weight_decay=0.0)

# #when trained with FoE included
optimizer_mye = torch.optim.Adam(mye.parameters(), lr=2*1e-5, betas=betas, weight_decay=0.0)
scheduler_mye = torch.optim.lr_scheduler.StepLR(optimizer_mye, step_size=20, gamma=0.9)

# proximal map related variables
lamb = 1.
alpha = 1.

noise_sd_for_training_stability = 0.0
n_epochs = 10
num_minibatches = 20 #for display

avg_loss_mye_paired = []

for epoch in np.arange(n_epochs):
    
    #restart scheduler and reset losses
    total_loss = 0.0
    total_gp_loss = 0.0
    total_pp_loss = 0.0
    
    for idx, batch in enumerate(train_dataloader):
        
        ############################################
        images = batch["ground_truth"].to(device) #true images
        batch_size = images.size()[0]
        
        #true images + slight noise for stability
        real_x = images + noise_sd_for_training_stability*torch.randn(batch_size,n_in_channels,img_size,img_size).to(device) 
        
        loss, gp_loss, pp_loss = compute_l1_mye_penalty(mye, real_x, alpha * lamb)
        
        #parameter update
        optimizer_mye.zero_grad()
        loss.backward()
        optimizer_mye.step()
        
        total_loss += loss.item()
        total_gp_loss += gp_loss.item()
        total_pp_loss += pp_loss.item()
        
        #clamp negative weights to 0
#         mye = clamp_weights(mye) 
        #take scheduler steps
        scheduler_mye.step()
        
        if(idx % num_minibatches == num_minibatches-1):
            ####### compute avg. loss over minibatches #######
            avg_loss = total_loss/num_minibatches
            avg_gp_loss = total_gp_loss/num_minibatches
            avg_pp_loss = total_pp_loss/num_minibatches
            
            avg_loss_mye_paired.append(avg_loss)
            
            #reset the losses
            total_loss = 0.0
            total_gp_loss = 0.0
            total_pp_loss = 0.0
            
            print('==================')
            print('----single convex MYE----')
            print("epoch: [{}/{}], mini-batch: [{}/{}], avg_loss: {:.8f}, avg_gp_loss: {:.8f}, avg_pp_loss: {:.8f}".\
                  format(epoch+1, n_epochs, idx+1, len(train_dataloader), avg_loss, avg_gp_loss, avg_pp_loss))
            
            print('--- response to true image ---')
            mye_output_true = mye(real_x)
            print('contribution of the leaky-relu network = %.6f'%torch.sum(mye_output_true))

#             mye_output_fbp = mye(fake_x)
#             print('--- response to FBP ---')
#             print('contribution of the leaky-relu network = %.6f'%torch.sum(acr_output_fbp))
#             print('contribution of the FoE network = %.6f'%torch.sum(foe_output_fbp))
#             print('contribution of the l2-term = %.6f'%torch.sum(l2_term_fbp))
    
            #save the models 
            pretrained_network_path = '../models/l1reg_pretrained_nets/'
            os.makedirs(pretrained_network_path, exist_ok=True)
#             torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
#             torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
#             torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_" + 'epoch_%02d'%epoch + ".pt") 

            torch.save(mye.state_dict(),  pretrained_network_path + "mye_new_model_foe_included_paired.pt")
# Out:
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [20/500], avg_loss: 100.93504868, avg_gp_loss: 96.00192413, avg_pp_loss: 4.93312602
# --- response to true image ---
# contribution of the leaky-relu network = 4.849798
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [40/500], avg_loss: 101.60371189, avg_gp_loss: 96.82981205, avg_pp_loss: 4.77390165
# --- response to true image ---
# contribution of the leaky-relu network = 4.688718
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [60/500], avg_loss: 106.39600410, avg_gp_loss: 101.77586346, avg_pp_loss: 4.62014081
# --- response to true image ---
# contribution of the leaky-relu network = 4.544022
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [80/500], avg_loss: 109.07340202, avg_gp_loss: 104.59612923, avg_pp_loss: 4.47727337
# --- response to true image ---
# contribution of the leaky-relu network = 4.403536
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [100/500], avg_loss: 97.94961224, avg_gp_loss: 93.61207867, avg_pp_loss: 4.33753426
# --- response to true image ---
# contribution of the leaky-relu network = 4.266163
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [120/500], avg_loss: 117.31107903, avg_gp_loss: 113.10412827, avg_pp_loss: 4.20695028
# --- response to true image ---
# contribution of the leaky-relu network = 4.136781
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [140/500], avg_loss: 103.24234314, avg_gp_loss: 99.15957909, avg_pp_loss: 4.08276401
# --- response to true image ---
# contribution of the leaky-relu network = 4.020160
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [160/500], avg_loss: 101.31030807, avg_gp_loss: 97.34167786, avg_pp_loss: 3.96863012
# --- response to true image ---
# contribution of the leaky-relu network = 3.913300
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [180/500], avg_loss: 100.02849693, avg_gp_loss: 96.16044884, avg_pp_loss: 3.86804857
# --- response to true image ---
# contribution of the leaky-relu network = 3.816905
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [200/500], avg_loss: 109.47310486, avg_gp_loss: 105.69807816, avg_pp_loss: 3.77502683
# --- response to true image ---
# contribution of the leaky-relu network = 3.727108
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [220/500], avg_loss: 102.07108917, avg_gp_loss: 98.38482323, avg_pp_loss: 3.68626637
# --- response to true image ---
# contribution of the leaky-relu network = 3.641387
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [240/500], avg_loss: 102.70510635, avg_gp_loss: 99.09922218, avg_pp_loss: 3.60588506
# --- response to true image ---
# contribution of the leaky-relu network = 3.565262
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [260/500], avg_loss: 106.40812645, avg_gp_loss: 102.87696953, avg_pp_loss: 3.53115638
# --- response to true image ---
# contribution of the leaky-relu network = 3.494883
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [280/500], avg_loss: 93.59707737, avg_gp_loss: 90.13347263, avg_pp_loss: 3.46360483
# --- response to true image ---
# contribution of the leaky-relu network = 3.429699
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [300/500], avg_loss: 96.51175079, avg_gp_loss: 93.11029434, avg_pp_loss: 3.40145622
# --- response to true image ---
# contribution of the leaky-relu network = 3.369558
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [320/500], avg_loss: 105.04846077, avg_gp_loss: 101.70423203, avg_pp_loss: 3.34422957
# --- response to true image ---
# contribution of the leaky-relu network = 3.316717
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [340/500], avg_loss: 102.06425934, avg_gp_loss: 98.77081795, avg_pp_loss: 3.29344133
# --- response to true image ---
# contribution of the leaky-relu network = 3.268017
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [360/500], avg_loss: 104.83939400, avg_gp_loss: 101.59223347, avg_pp_loss: 3.24716059
# --- response to true image ---
# contribution of the leaky-relu network = 3.223346
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [380/500], avg_loss: 108.34086113, avg_gp_loss: 105.13629608, avg_pp_loss: 3.20456558
# --- response to true image ---
# contribution of the leaky-relu network = 3.183292
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [400/500], avg_loss: 109.61755295, avg_gp_loss: 106.45184250, avg_pp_loss: 3.16570996
# --- response to true image ---
# contribution of the leaky-relu network = 3.146830
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [420/500], avg_loss: 104.53556385, avg_gp_loss: 101.40370178, avg_pp_loss: 3.13186325
# --- response to true image ---
# contribution of the leaky-relu network = 3.115031
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [440/500], avg_loss: 102.81160355, avg_gp_loss: 99.71046257, avg_pp_loss: 3.10114033
# --- response to true image ---
# contribution of the leaky-relu network = 3.085418
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [460/500], avg_loss: 105.77852364, avg_gp_loss: 102.70502815, avg_pp_loss: 3.07349466
# --- response to true image ---
# contribution of the leaky-relu network = 3.060071
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [480/500], avg_loss: 112.52167549, avg_gp_loss: 109.47260799, avg_pp_loss: 3.04906813
# --- response to true image ---
# contribution of the leaky-relu network = 3.037024
# ==================
# ----single convex MYE----
# epoch: [1/10], mini-batch: [500/500], avg_loss: 105.51419411, avg_gp_loss: 102.48687630, avg_pp_loss: 3.02731848
# --- response to true image ---
# contribution of the leaky-relu network = 3.016223
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [20/500], avg_loss: 105.56044540, avg_gp_loss: 102.55308037, avg_pp_loss: 3.00736476
# --- response to true image ---
# contribution of the leaky-relu network = 2.997286
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [40/500], avg_loss: 106.34151535, avg_gp_loss: 103.35230255, avg_pp_loss: 2.98921313
# --- response to true image ---
# contribution of the leaky-relu network = 2.980484
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [60/500], avg_loss: 100.67144279, avg_gp_loss: 97.69844170, avg_pp_loss: 2.97300087
# --- response to true image ---
# contribution of the leaky-relu network = 2.965094
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [80/500], avg_loss: 101.74992714, avg_gp_loss: 98.79153595, avg_pp_loss: 2.95839001
# --- response to true image ---
# contribution of the leaky-relu network = 2.951135
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [100/500], avg_loss: 100.73485870, avg_gp_loss: 97.78965569, avg_pp_loss: 2.94520260
# --- response to true image ---
# contribution of the leaky-relu network = 2.938491
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [120/500], avg_loss: 101.04588432, avg_gp_loss: 98.11278706, avg_pp_loss: 2.93309749
# --- response to true image ---
# contribution of the leaky-relu network = 2.926978
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [140/500], avg_loss: 106.11593285, avg_gp_loss: 103.19402390, avg_pp_loss: 2.92190924
# --- response to true image ---
# contribution of the leaky-relu network = 2.916635
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [160/500], avg_loss: 117.88268509, avg_gp_loss: 114.97061005, avg_pp_loss: 2.91207500
# --- response to true image ---
# contribution of the leaky-relu network = 2.906945
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [180/500], avg_loss: 101.58593369, avg_gp_loss: 98.68306694, avg_pp_loss: 2.90286771
# --- response to true image ---
# contribution of the leaky-relu network = 2.898600
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [200/500], avg_loss: 105.36418190, avg_gp_loss: 102.46899338, avg_pp_loss: 2.89518839
# --- response to true image ---
# contribution of the leaky-relu network = 2.891510
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [220/500], avg_loss: 104.96530266, avg_gp_loss: 102.07694016, avg_pp_loss: 2.88836221
# --- response to true image ---
# contribution of the leaky-relu network = 2.884883
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [240/500], avg_loss: 101.01027813, avg_gp_loss: 98.12826290, avg_pp_loss: 2.88201461
# --- response to true image ---
# contribution of the leaky-relu network = 2.878994
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [260/500], avg_loss: 107.68645172, avg_gp_loss: 104.81011181, avg_pp_loss: 2.87633957
# --- response to true image ---
# contribution of the leaky-relu network = 2.873616
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [280/500], avg_loss: 104.90910149, avg_gp_loss: 102.03773804, avg_pp_loss: 2.87136395
# --- response to true image ---
# contribution of the leaky-relu network = 2.868681
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [300/500], avg_loss: 105.51751595, avg_gp_loss: 102.65100746, avg_pp_loss: 2.86650909
# --- response to true image ---
# contribution of the leaky-relu network = 2.864122
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [320/500], avg_loss: 105.29007034, avg_gp_loss: 102.42780724, avg_pp_loss: 2.86226324
# --- response to true image ---
# contribution of the leaky-relu network = 2.860225
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [340/500], avg_loss: 96.98864365, avg_gp_loss: 94.13006401, avg_pp_loss: 2.85857978
# --- response to true image ---
# contribution of the leaky-relu network = 2.856671
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [360/500], avg_loss: 101.44803352, avg_gp_loss: 98.59292126, avg_pp_loss: 2.85511111
# --- response to true image ---
# contribution of the leaky-relu network = 2.853473
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [380/500], avg_loss: 105.95477295, avg_gp_loss: 103.10272293, avg_pp_loss: 2.85204999
# --- response to true image ---
# contribution of the leaky-relu network = 2.850466
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [400/500], avg_loss: 97.61381989, avg_gp_loss: 94.76467285, avg_pp_loss: 2.84914725
# --- response to true image ---
# contribution of the leaky-relu network = 2.847724
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [420/500], avg_loss: 98.05848637, avg_gp_loss: 95.21187916, avg_pp_loss: 2.84660741
# --- response to true image ---
# contribution of the leaky-relu network = 2.845384
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [440/500], avg_loss: 104.66217537, avg_gp_loss: 101.81782036, avg_pp_loss: 2.84435483
# --- response to true image ---
# contribution of the leaky-relu network = 2.843214
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [460/500], avg_loss: 93.80138149, avg_gp_loss: 90.95901852, avg_pp_loss: 2.84236380
# --- response to true image ---
# contribution of the leaky-relu network = 2.841416
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [480/500], avg_loss: 112.05329475, avg_gp_loss: 109.21267891, avg_pp_loss: 2.84061435
# --- response to true image ---
# contribution of the leaky-relu network = 2.839743
# ==================
# ----single convex MYE----
# epoch: [2/10], mini-batch: [500/500], avg_loss: 101.64686356, avg_gp_loss: 98.80787506, avg_pp_loss: 2.83898877
# --- response to true image ---
# contribution of the leaky-relu network = 2.838192
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [20/500], avg_loss: 102.56771927, avg_gp_loss: 99.73020554, avg_pp_loss: 2.83751450
# --- response to true image ---
# contribution of the leaky-relu network = 2.836774
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [40/500], avg_loss: 104.10221748, avg_gp_loss: 101.26602974, avg_pp_loss: 2.83618634
# --- response to true image ---
# contribution of the leaky-relu network = 2.835524
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [60/500], avg_loss: 98.99846840, avg_gp_loss: 96.16347961, avg_pp_loss: 2.83498888
# --- response to true image ---
# contribution of the leaky-relu network = 2.834396
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [80/500], avg_loss: 110.95418205, avg_gp_loss: 108.12024117, avg_pp_loss: 2.83394072
# --- response to true image ---
# contribution of the leaky-relu network = 2.833413
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [100/500], avg_loss: 101.87552338, avg_gp_loss: 99.04252357, avg_pp_loss: 2.83299969
# --- response to true image ---
# contribution of the leaky-relu network = 2.832535
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [120/500], avg_loss: 107.50865326, avg_gp_loss: 104.67649498, avg_pp_loss: 2.83215888
# --- response to true image ---
# contribution of the leaky-relu network = 2.831724
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [140/500], avg_loss: 98.04296989, avg_gp_loss: 95.21159973, avg_pp_loss: 2.83137033
# --- response to true image ---
# contribution of the leaky-relu network = 2.830975
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [160/500], avg_loss: 104.34988575, avg_gp_loss: 101.51922131, avg_pp_loss: 2.83066511
# --- response to true image ---
# contribution of the leaky-relu network = 2.830328
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [180/500], avg_loss: 101.58068466, avg_gp_loss: 98.75064507, avg_pp_loss: 2.83003963
# --- response to true image ---
# contribution of the leaky-relu network = 2.829713
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [200/500], avg_loss: 102.71453743, avg_gp_loss: 99.88507881, avg_pp_loss: 2.82945958
# --- response to true image ---
# contribution of the leaky-relu network = 2.829181
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [220/500], avg_loss: 107.00730705, avg_gp_loss: 104.17836151, avg_pp_loss: 2.82894545
# --- response to true image ---
# contribution of the leaky-relu network = 2.828693
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [240/500], avg_loss: 107.51364803, avg_gp_loss: 104.68515396, avg_pp_loss: 2.82849395
# --- response to true image ---
# contribution of the leaky-relu network = 2.828274
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [260/500], avg_loss: 103.61964760, avg_gp_loss: 100.79156036, avg_pp_loss: 2.82808725
# --- response to true image ---
# contribution of the leaky-relu network = 2.827882
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [280/500], avg_loss: 107.21565170, avg_gp_loss: 104.38794098, avg_pp_loss: 2.82771143
# --- response to true image ---
# contribution of the leaky-relu network = 2.827527
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [300/500], avg_loss: 103.46964569, avg_gp_loss: 100.64226189, avg_pp_loss: 2.82738392
# --- response to true image ---
# contribution of the leaky-relu network = 2.827223
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [320/500], avg_loss: 110.99382896, avg_gp_loss: 108.16673622, avg_pp_loss: 2.82709378
# --- response to true image ---
# contribution of the leaky-relu network = 2.826946
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [340/500], avg_loss: 98.92664719, avg_gp_loss: 96.09981995, avg_pp_loss: 2.82682700
# --- response to true image ---
# contribution of the leaky-relu network = 2.826696
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [360/500], avg_loss: 101.36257362, avg_gp_loss: 98.53598671, avg_pp_loss: 2.82658707
# --- response to true image ---
# contribution of the leaky-relu network = 2.826464
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [380/500], avg_loss: 109.57333584, avg_gp_loss: 106.74696655, avg_pp_loss: 2.82636836
# --- response to true image ---
# contribution of the leaky-relu network = 2.826256
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [400/500], avg_loss: 106.19198914, avg_gp_loss: 103.36581497, avg_pp_loss: 2.82617413
# --- response to true image ---
# contribution of the leaky-relu network = 2.826077
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [420/500], avg_loss: 104.02279587, avg_gp_loss: 101.19680462, avg_pp_loss: 2.82599216
# --- response to true image ---
# contribution of the leaky-relu network = 2.825902
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [440/500], avg_loss: 96.07734871, avg_gp_loss: 93.25151978, avg_pp_loss: 2.82582901
# --- response to true image ---
# contribution of the leaky-relu network = 2.825752
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [460/500], avg_loss: 103.64967308, avg_gp_loss: 100.82399178, avg_pp_loss: 2.82568139
# --- response to true image ---
# contribution of the leaky-relu network = 2.825606
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [480/500], avg_loss: 103.36299553, avg_gp_loss: 100.53744926, avg_pp_loss: 2.82554703
# --- response to true image ---
# contribution of the leaky-relu network = 2.825481
# ==================
# ----single convex MYE----
# epoch: [3/10], mini-batch: [500/500], avg_loss: 91.34370193, avg_gp_loss: 88.51826897, avg_pp_loss: 2.82543323
# --- response to true image ---
# contribution of the leaky-relu network = 2.825382
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [20/500], avg_loss: 108.92870407, avg_gp_loss: 106.10337639, avg_pp_loss: 2.82532682
# --- response to true image ---
# contribution of the leaky-relu network = 2.825269
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [40/500], avg_loss: 105.90393105, avg_gp_loss: 103.07870102, avg_pp_loss: 2.82523024
# --- response to true image ---
# contribution of the leaky-relu network = 2.825184
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [60/500], avg_loss: 100.95589752, avg_gp_loss: 98.13075218, avg_pp_loss: 2.82514608
# --- response to true image ---
# contribution of the leaky-relu network = 2.825105
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [80/500], avg_loss: 106.03490906, avg_gp_loss: 103.20984039, avg_pp_loss: 2.82506906
# --- response to true image ---
# contribution of the leaky-relu network = 2.825029
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [100/500], avg_loss: 107.63938370, avg_gp_loss: 104.81438484, avg_pp_loss: 2.82499942
# --- response to true image ---
# contribution of the leaky-relu network = 2.824966
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [120/500], avg_loss: 99.69782391, avg_gp_loss: 96.87288456, avg_pp_loss: 2.82493970
# --- response to true image ---
# contribution of the leaky-relu network = 2.824908
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [140/500], avg_loss: 114.26358299, avg_gp_loss: 111.43869972, avg_pp_loss: 2.82488265
# --- response to true image ---
# contribution of the leaky-relu network = 2.824856
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [160/500], avg_loss: 100.30471077, avg_gp_loss: 97.47987595, avg_pp_loss: 2.82483435
# --- response to true image ---
# contribution of the leaky-relu network = 2.824806
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [180/500], avg_loss: 104.89095993, avg_gp_loss: 102.06617336, avg_pp_loss: 2.82478627
# --- response to true image ---
# contribution of the leaky-relu network = 2.824766
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [200/500], avg_loss: 102.58902550, avg_gp_loss: 99.76428089, avg_pp_loss: 2.82474542
# --- response to true image ---
# contribution of the leaky-relu network = 2.824723
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [220/500], avg_loss: 102.29126015, avg_gp_loss: 99.46655159, avg_pp_loss: 2.82470912
# --- response to true image ---
# contribution of the leaky-relu network = 2.824690
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [240/500], avg_loss: 106.88552399, avg_gp_loss: 104.06085167, avg_pp_loss: 2.82467260
# --- response to true image ---
# contribution of the leaky-relu network = 2.824653
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [260/500], avg_loss: 98.31315098, avg_gp_loss: 95.48850880, avg_pp_loss: 2.82464334
# --- response to true image ---
# contribution of the leaky-relu network = 2.824630
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [280/500], avg_loss: 101.75683880, avg_gp_loss: 98.93222523, avg_pp_loss: 2.82461389
# --- response to true image ---
# contribution of the leaky-relu network = 2.824601
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [300/500], avg_loss: 96.58186111, avg_gp_loss: 93.75726891, avg_pp_loss: 2.82459203
# --- response to true image ---
# contribution of the leaky-relu network = 2.824582
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [320/500], avg_loss: 108.79973488, avg_gp_loss: 105.97516251, avg_pp_loss: 2.82457229
# --- response to true image ---
# contribution of the leaky-relu network = 2.824564
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [340/500], avg_loss: 96.65397949, avg_gp_loss: 93.82942142, avg_pp_loss: 2.82455817
# --- response to true image ---
# contribution of the leaky-relu network = 2.824551
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [360/500], avg_loss: 103.86729622, avg_gp_loss: 101.04275303, avg_pp_loss: 2.82454331
# --- response to true image ---
# contribution of the leaky-relu network = 2.824536
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [380/500], avg_loss: 108.64660034, avg_gp_loss: 105.82206974, avg_pp_loss: 2.82452997
# --- response to true image ---
# contribution of the leaky-relu network = 2.824519
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [400/500], avg_loss: 97.67316418, avg_gp_loss: 94.84864521, avg_pp_loss: 2.82451938
# --- response to true image ---
# contribution of the leaky-relu network = 2.824517
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [420/500], avg_loss: 107.49855232, avg_gp_loss: 104.67404251, avg_pp_loss: 2.82450851
# --- response to true image ---
# contribution of the leaky-relu network = 2.824501
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [440/500], avg_loss: 103.87665329, avg_gp_loss: 101.05215454, avg_pp_loss: 2.82449868
# --- response to true image ---
# contribution of the leaky-relu network = 2.824496
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [460/500], avg_loss: 103.62602615, avg_gp_loss: 100.80153809, avg_pp_loss: 2.82448989
# --- response to true image ---
# contribution of the leaky-relu network = 2.824487
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [480/500], avg_loss: 96.38034134, avg_gp_loss: 93.55585747, avg_pp_loss: 2.82448366
# --- response to true image ---
# contribution of the leaky-relu network = 2.824482
# ==================
# ----single convex MYE----
# epoch: [4/10], mini-batch: [500/500], avg_loss: 102.84772873, avg_gp_loss: 100.02325096, avg_pp_loss: 2.82447723
# --- response to true image ---
# contribution of the leaky-relu network = 2.824472
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [20/500], avg_loss: 104.89208660, avg_gp_loss: 102.06761551, avg_pp_loss: 2.82447100
# --- response to true image ---
# contribution of the leaky-relu network = 2.824474
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [40/500], avg_loss: 99.17609806, avg_gp_loss: 96.35163078, avg_pp_loss: 2.82446660
# --- response to true image ---
# contribution of the leaky-relu network = 2.824462
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [60/500], avg_loss: 102.30320053, avg_gp_loss: 99.47873878, avg_pp_loss: 2.82446200
# --- response to true image ---
# contribution of the leaky-relu network = 2.824460
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [80/500], avg_loss: 107.02057495, avg_gp_loss: 104.19612007, avg_pp_loss: 2.82445676
# --- response to true image ---
# contribution of the leaky-relu network = 2.824454
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [100/500], avg_loss: 106.43418503, avg_gp_loss: 103.60973320, avg_pp_loss: 2.82445109
# --- response to true image ---
# contribution of the leaky-relu network = 2.824446
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [120/500], avg_loss: 109.14216537, avg_gp_loss: 106.31771870, avg_pp_loss: 2.82444607
# --- response to true image ---
# contribution of the leaky-relu network = 2.824447
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch: [140/500], avg_loss: 99.51864090, avg_gp_loss: 96.69419937, avg_pp_loss: 2.82444173
# --- response to true image ---
# contribution of the leaky-relu network = 2.824444
# ==================
# ----single convex MYE----
# epoch: [5/10], mini-batch:
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [440/500], avg_loss: 113.46369362, avg_gp_loss: 110.63926239, avg_pp_loss: 2.82442985
# --- response to true image ---
# contribution of the leaky-relu network = 2.824431
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [460/500], avg_loss: 102.05957451, avg_gp_loss: 99.23514290, avg_pp_loss: 2.82443107
# --- response to true image ---
# contribution of the leaky-relu network = 2.824429
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [480/500], avg_loss: 109.71990032, avg_gp_loss: 106.89547024, avg_pp_loss: 2.82442961
# --- response to true image ---
# contribution of the leaky-relu network = 2.824424
# ==================
# ----single convex MYE----
# epoch: [10/10], mini-batch: [500/500], avg_loss: 105.94019852, avg_gp_loss: 103.11576710, avg_pp_loss: 2.82443016
# --- response to true image ---
# contribution of the leaky-relu network = 2.824431

# %%
#save the models 
pretrained_network_path = '../models/l1reg_pretrained_nets/'
os.makedirs(pretrained_network_path, exist_ok=True)
# torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
# torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_" + 'epoch_%02d'%epoch + ".pt") 
# torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_" + 'epoch_%02d'%epoch + ".pt") 

# torch.save(acr.state_dict(),  pretrained_network_path + "acr_new_model_foe_included_paired.pt")
# torch.save(foe.state_dict(),  pretrained_network_path + "foe_net_foe_included_paired.pt")
# torch.save(l2_net.state_dict(),  pretrained_network_path + "l2_term_foe_included_paired.pt")

# %%
import matplotlib.pyplot as plt
pretrained_network_path = '../models/l1reg_pretrained_nets/'

avg_loss_mye_paired_arr = np.array(avg_loss_mye_paired, dtype=np.float32)
# avg_loss_mye_unpaired_arr = np.load(pretrained_network_path + "avg_loss_mye_unpaired_arr.npy")
np.save(pretrained_network_path + "avg_loss_mye_paired_arr.npy", avg_loss_mye_paired_arr)
train_steps = np.arange(1, 1+avg_loss_mye_paired_arr.size)

# plt.plot(train_steps, avg_loss_mye_paired_arr, 'r', train_steps, avg_loss_acr_unpaired_arr, 'b', linewidth=2.0)
# plt.legend(['paired', 'unpaired'], fontsize=24.0)


plt.plot(train_steps, avg_loss_mye_paired_arr, 'r', linewidth=2.0)

# plt.plot(train_steps, avg_loss_mye_unpaired_arr, 'b', linewidth=2.0)

plt.gcf().set_size_inches(11.0,8.0)
plt.xlabel('training steps', fontsize=28.0)
plt.ylabel('training loss', fontsize=28.0)
plt.tick_params(axis='both', which='major', labelsize=24.0)
plt.grid()

plt.savefig(pretrained_network_path + 'unpaired_train.png', bbox_inches='tight', transparent = False, pad_inches=0.1)
#plt.savefig(pretrained_network_path + 'paired_vs_unpaired_train_combined.png', bbox_inches='tight', transparent = False, pad_inches=0.1)
#plt.savefig(pretrained_network_path + 'paired_train.png', bbox_inches='tight', transparent = False, pad_inches=0.1)

plt.show()

# %%
#check convexity of the net
n_trials = 50
convexity = 0
for trial in np.arange(n_trials):
    x1 = torch.rand(dummy_input.size()).to(device)
    x2 = torch.rand(dummy_input.size()).to(device)
    alpha = torch.rand(1).to(device)

    cvx_combo_of_input = mye(alpha * x1 + (1-alpha)*x2)
    cvx_combo_of_output = alpha * mye(x1) + (1-alpha)*mye(x2)

    convexity += (cvx_combo_of_input.mean() <= cvx_combo_of_output.mean())
if(convexity == n_trials):
    print('the net is %s'%'convex') 
else:
    print('the net is %s'%'non-convex')

# %%
# compare output to exact solution (Does not work yet for this approach)
steps = 1000
x_ij = torch.linspace(start=-0.5, end=0.5,steps=steps)
print((steps,) + real_x[0].shape)
x = torch.zeros((steps,) + real_x[0].shape)
x[:,0,2,3] = x_ij
g_lambda = mye(x)

def soft_shrinkage(el,lamb,alpha):
    if el.abs() <= lamb*alpha:
        return 1/(2*lamb*alpha) * el**2
    else:
        return el.abs() - lamb*alpha/2
        
    
        
gt = np.array([soft_shrinkage(el,alpha,lamb) for el in x_ij])

plt.plot(x_ij.detach().numpy(),g_lambda.detach().numpy())
plt.plot(x_ij.detach().numpy(),gt)
# Plot ground truth

plt.show()
